# %% [markdown]
# **Earthquake Casetudy**
#
# The National Earthquake Information Center (NEIC) determines the location and size of
# all significant earthquakes that occur worldwide and disseminates this information
# immediately to national and international agencies, scientists, critical facilities, and the
# general public. The NEIC compiles and provides to scientists and to the public an
# extensive seismic database that serves as a foundation for scientific research through
# the operation of modern digital national and global seismograph networks and
# cooperative international agreements. The NEIC is the national data center and archive
# for earthquake information.
# This dataset includes a record of the date, time, location, depth, magnitude, and source
# of every earthquake with a reported magnitude 5.5 or higher since 1965.

# %%
#Import Libraries
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

# %%
data1=pd.read_csv('C:/Users/wilp-hyd/Desktop/Desktop Folders/santosh/earthquake.csv')

# %%
data1.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type    ...      \
# 0                     NaN        6.0             MW    ...
# 1                     NaN        5.8             MW    ...
# 2                     NaN        6.2             MW    ...
# 3                     NaN        5.8             MW    ...
# 4                     NaN        5.8             MW    ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
data1.describe()
# Out:
#            Latitude     Longitude         Depth  Depth Error  \
# count  23412.000000  23412.000000  23412.000000  4461.000000
# mean       1.679033     39.639961     70.767911     4.993115
# std       30.113183    125.511959    122.651898     4.875184
# min      -77.080000   -179.997000     -1.100000     0.000000
# 25%      -18.653000    -76.349750     14.522500     1.800000
# 50%       -3.568500    103.982000     33.000000     3.500000
# 75%       26.190750    145.026250     54.000000     6.300000
# max       86.005000    179.998000    700.000000    91.295000
#
#        Depth Seismic Stations     Magnitude  Magnitude Error  \
# count             7097.000000  23412.000000       327.000000
# mean               275.364098      5.882531         0.071820
# std                162.141631      0.423066         0.051466
# min                  0.000000      5.500000         0.000000
# 25%                146.000000      5.600000         0.046000
# ...

# %%
data2=data1[['Date','Time','Latitude','Longitude','Type','Depth','Magnitude','Magnitude Type','ID','Status']]

# %%
data2.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Magnitude  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6        6.0
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0        5.8
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0        6.2
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0        5.8
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0        5.8
#
#   Magnitude Type            ID     Status
# 0             MW  ISCGEM860706  Automatic
# 1             MW  ISCGEM860737  Automatic
# 2             MW  ISCGEM860762  Automatic
# 3             MW  ISCGEM860856  Automatic
# 4             MW  ISCGEM860890  Automatic

# %%
data2.describe()
# Out:
#            Latitude     Longitude         Depth     Magnitude
# count  23412.000000  23412.000000  23412.000000  23412.000000
# mean       1.679033     39.639961     70.767911      5.882531
# std       30.113183    125.511959    122.651898      0.423066
# min      -77.080000   -179.997000     -1.100000      5.500000
# 25%      -18.653000    -76.349750     14.522500      5.600000
# 50%       -3.568500    103.982000     33.000000      5.700000
# 75%       26.190750    145.026250     54.000000      6.000000
# max       86.005000    179.998000    700.000000      9.100000

# %% [markdown]
# Here these selected columns which I want to use seems to be clean
# Additionally, we have Date, Time, Type, Magnitude Type, ID, Source

# %%
#I want to work only on 'Earthquake' Data
data2=data2[(data2.Type=='Earthquake')]
data2.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Magnitude  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6        6.0
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0        5.8
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0        6.2
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0        5.8
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0        5.8
#
#   Magnitude Type            ID     Status
# 0             MW  ISCGEM860706  Automatic
# 1             MW  ISCGEM860737  Automatic
# 2             MW  ISCGEM860762  Automatic
# 3             MW  ISCGEM860856  Automatic
# 4             MW  ISCGEM860890  Automatic

# %%
data2['Magnitude'].describe()
# Out:
# count    23232.000000
# mean         5.882763
# std          0.424032
# min          5.500000
# 25%          5.600000
# 50%          5.700000
# 75%          6.000000
# max          9.100000
# Name: Magnitude, dtype: float64

# %%
Earthquake = data1[data1['Type']=='Earthquake']['Magnitude Type'].value_counts()
Explosions = data1[data1['Type']=='Explosions']['Magnitude Type'].value_counts()
Nukes = data1[data1['Type']=='Nuclear Explosions']['Magnitude Type'].value_counts()
df=pd.DataFrame([Earthquake,Explosions,Nukes])
df.index=['Earthquake','Explosions','Nukes']
df.plot(kind='bar',stacked=True, figsize=(15,8))

# %%
data2.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Magnitude  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6        6.0
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0        5.8
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0        6.2
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0        5.8
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0        5.8
#
#   Magnitude Type            ID     Status
# 0             MW  ISCGEM860706  Automatic
# 1             MW  ISCGEM860737  Automatic
# 2             MW  ISCGEM860762  Automatic
# 3             MW  ISCGEM860856  Automatic
# 4             MW  ISCGEM860890  Automatic

# %%
# Want to plot Mean Magnitudes for Multiple Magnitude Types
MB=data2[data2['Magnitude Type']=='MB']['Magnitude'].mean()
MD=data2[data2['Magnitude Type']=='MD']['Magnitude'].mean()
MH=data2[data2['Magnitude Type']=='MH']['Magnitude'].mean()
ML=data2[data2['Magnitude Type']=='ML']['Magnitude'].mean()
MS=data2[data2['Magnitude Type']=='MS']['Magnitude'].mean()
MW=data2[data2['Magnitude Type']=='MW']['Magnitude'].mean()
MWB=data2[data2['Magnitude Type']=='MWB']['Magnitude'].mean()
MWC=data2[data2['Magnitude Type']=='MWC']['Magnitude'].mean()
MWR=data2[data2['Magnitude Type']=='MWR']['Magnitude'].mean()
MWW=data2[data2['Magnitude Type']=='MWB']['Magnitude'].mean()
df=pd.DataFrame([MB,MD,MH,ML,MS,MW,MWB,MWC,MWR,MWW])
df.index=['MB','MD','MH','ML','MS','MW','MWB','MWC','MWR','MWW']
df.plot(kind='bar',stacked=False,figsize=(15,8))

# %% [markdown]
# Highest Mean Magnitude seems to be for 'MH' and least for 'MWR'

# %%
# Want to plot Mean Depths for Multiple Magnitude Types
MB=data2[data2['Magnitude Type']=='MB']['Depth'].mean()
MD=data2[data2['Magnitude Type']=='MD']['Depth'].mean()
MH=data2[data2['Magnitude Type']=='MH']['Depth'].mean()
ML=data2[data2['Magnitude Type']=='ML']['Depth'].mean()
MS=data2[data2['Magnitude Type']=='MS']['Depth'].mean()
MW=data2[data2['Magnitude Type']=='MW']['Depth'].mean()
MWB=data2[data2['Magnitude Type']=='MWB']['Depth'].mean()
MWC=data2[data2['Magnitude Type']=='MWC']['Depth'].mean()
MWR=data2[data2['Magnitude Type']=='MWR']['Depth'].mean()
MWW=data2[data2['Magnitude Type']=='MWB']['Depth'].mean()
df=pd.DataFrame([MB,MD,MH,ML,MS,MW,MWB,MWC,MWR,MWW])
df.index=['MB','MD','MH','ML','MS','MW','MWB','MWC','MWR','MWW']
df.plot(kind='bar',stacked=False,figsize=(15,8))

# %%
data2.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Magnitude  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6        6.0
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0        5.8
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0        6.2
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0        5.8
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0        5.8
#
#   Magnitude Type            ID     Status
# 0             MW  ISCGEM860706  Automatic
# 1             MW  ISCGEM860737  Automatic
# 2             MW  ISCGEM860762  Automatic
# 3             MW  ISCGEM860856  Automatic
# 4             MW  ISCGEM860890  Automatic

# %% [markdown]
# Highest Depth for MB and least for MH

# %%
# Histogram for Depth and Magnitude
figure = plt.figure(figsize=(15,8))
plt.hist(data2.Magnitude,bins=20)
plt.xlabel('Magnitude')
plt.ylabel('No. of Earthquakes')
plt.legend()

figure = plt.figure(figsize=(15,8))
plt.hist(data2.Depth,bins=15)
plt.xlabel('Depth')
plt.ylabel('No. of Earthquakes')
plt.legend()

# %%
data2.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Magnitude  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6        6.0
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0        5.8
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0        6.2
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0        5.8
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0        5.8
#
#   Magnitude Type            ID     Status
# 0             MW  ISCGEM860706  Automatic
# 1             MW  ISCGEM860737  Automatic
# 2             MW  ISCGEM860762  Automatic
# 3             MW  ISCGEM860856  Automatic
# 4             MW  ISCGEM860890  Automatic

# %%
# Work on date and time
import datetime
import random

# %%
data2['Date']=pd.to_datetime(data2.Date)
data2['Month']=pd.DatetimeIndex(data2.Date).month
data2['Year']=pd.DatetimeIndex(data2.Date).year
col=['Date','Year','Month','Magnitude','Depth']
data2[col].sort(['Date'],ascending=True).head()
# Out:
#         Date  Year  Month  Magnitude  Depth
# 0 1965-01-02  1965      1        6.0  131.6
# 1 1965-01-04  1965      1        5.8   80.0
# 2 1965-01-05  1965      1        6.2   20.0
# 3 1965-01-08  1965      1        5.8   15.0
# 4 1965-01-09  1965      1        5.8   15.0

# %%
#Month Wise No. of Earthquakes
data2.head()
plt.hist(data2['Month'],bins=12,color="blue")
plt.title("Month Wise No. of Earthquakes")
plt.ylabel('Number of Earthquakes')
plt.xlabel('Month')

# %%
#Year Wise No. of Earthquakes
data2.head()
plt.hist(data2['Year'],bins=12,color="brown")
plt.title("Year Wise No. of Earthquakes")
plt.ylabel('Number of Earthquakes')
plt.xlabel('Year')

# %% [markdown]
# Analysis: Between Feb and Apr [Specifically Mar and Apr] of any years we have higher no. of earthquakes.
# Year on Year there is largely an increase in the No. of Earthquakes

# %%
data2.groupby('Month').mean()['Magnitude'].plot(kind='bar',figsize=[15,8])

# %%
data2.groupby('Month').mean()['Depth'].plot(kind='bar',figsize=[15,8])

# %% [markdown]
# Analysis: Mean earthquake magnitudes are almost same in all the months, whereas the mean depth of earthquake is maximum in Jan, Aug and Nov

# %%
cols = ['Time', 'Magnitude']
data2[cols].sort(['Time'],ascending=True).head()
data2[cols].head()
# Out:
#        Time  Magnitude
# 0  13:44:18        6.0
# 1  11:29:49        5.8
# 2  18:05:58        6.2
# 3  18:49:43        5.8
# 4  13:32:50        5.8

# %%
data2['Hour']=pd.to_datetime(data2['Time']).dt.hour
data2['Minute']=pd.to_datetime(data2['Time']).dt.minute / 60
data2['Hour-Minute']=data2['Hour']+data2['Minute']
cols = ['Time','Hour','Minute', 'Magnitude','Hour-Minute']
data2 [cols].head()

plt.hist(data2['Hour-Minute'],bins=12,color="blue")
plt.title("Time Wise No. of Earthquakes")
plt.ylabel('Number of Earthquakes')
plt.xlabel('Time')

# %% [markdown]
# Analysis: Almost every time of the day there are almost similar no. of earthquakes as per bar chart, but lets see with line chart

# %%
data2.groupby('Hour').mean()['Magnitude'].plot(kind='line',figsize=[15,8])

# %% [markdown]
# Analysis: 20:00 to 23:00 and 0:00 to 03:00 its increasing magnitudes of earthquakes

# %%
# Work on Latitude and Longitude
data2.groupby('Latitude').mean()['Magnitude'].plot(kind='line',figsize=[15,8])

# %%
# Work on Scatter plots & Bivariate Distributions

plt.scatter(data2['Longitude'],data2['Latitude'],10,"red",alpha=1)
plt.title("Longitude Vs Latitude : No. of Earthquakes")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

# %% [markdown]
# Analysis: At Longitude range 0 to 150 & Latitude Range -25 to 50 there seems to be many earthquakes

# %%
from mpl_toolkits.basemap import Basemap

# %%
data2['Longitude'].head(100)
# Out:
# 0     145.616
# 1     127.352
# 2    -173.972
# 3     -23.557
# 4     126.427
# 5     166.629
# 6      87.867
# 7     166.212
# 8     -27.043
# 9     178.487
# 10    108.988
# 11    125.952
# 12    161.703
# 13   -177.864
# 14     73.251
# 15    139.741
# 16    178.715
# 17    175.055
# 18    172.007
# 19    175.746
# 20    177.848
# 21    173.975
# 22    173.058
# 23    172.588
# 24    174.368
# 25    173.969
# 26    179.605
# 27    171.974
# 28    174.696
# 29    171.091
#        ...
# 70    121.148
# 71    173.911
# 72    -92.623
# 73     28.226
# 74   -177.262
# 75    151.819
# 76    171.308
# 77    146.993
# 78    179.511
# 79    174.937
# 80    -63.214
# 81    174.239
# 82   -132.923
# 83    121.461
# 84   -177.968
# 85     23.860
# 86   -162.331
# 87     70.724
# 88    121.117
# 89    143.032
# 90    171.821
# 91   -175.890
# 92    -26.758
# 93    119.836
# 94    126.623
# 95   -173.254
# 96    -71.573
# 97   -173.194
# 98    126.553
# 99    161.904
# ...

# %%
data2.head()
# Out:
#         Date      Time  Latitude  Longitude        Type  Depth  Magnitude  \
# 0 1965-01-02  13:44:18    19.246    145.616  Earthquake  131.6        6.0
# 1 1965-01-04  11:29:49     1.863    127.352  Earthquake   80.0        5.8
# 2 1965-01-05  18:05:58   -20.579   -173.972  Earthquake   20.0        6.2
# 3 1965-01-08  18:49:43   -59.076    -23.557  Earthquake   15.0        5.8
# 4 1965-01-09  13:32:50    11.938    126.427  Earthquake   15.0        5.8
#
#   Magnitude Type            ID     Status  Month  Year  Hour    Minute  \
# 0             MW  ISCGEM860706  Automatic      1  1965    13  0.733333
# 1             MW  ISCGEM860737  Automatic      1  1965    11  0.483333
# 2             MW  ISCGEM860762  Automatic      1  1965    18  0.083333
# 3             MW  ISCGEM860856  Automatic      1  1965    18  0.816667
# 4             MW  ISCGEM860890  Automatic      1  1965    13  0.533333
#
#    Hour-Minute
# 0    13.733333
# 1    11.483333
# 2    18.083333
# 3    18.816667
# ...

# %%
s=data2['Longitude']
b=s.values

# %%
t=data2['Latitude']
a=t.values

# %%
u=data2['Magnitude']
c=u.values

# %%
# Geo Maps with Sample Harcoded Data

m = Basemap(projection='mill',llcrnrlat=-90,urcrnrlat=90,llcrnrlon=-180,urcrnrlon=180,resolution='c')
plt.figure(figsize=(50,30))

m.drawcoastlines()
m.drawcountries()
#m.drawstates()
#m.drawrivers()
m.fillcontinents(color='#04BAE3',lake_color='#FFFFFF')

i=0
for i in range(0,10000,1): # can extend the data for all point.s
    x,y=m(b[i],a[i],False)
    if c[i]>6:
        m.plot(x,y,'ro',markersize=25,alpha=0.5)
    else:
        m.plot(x,y,'go',markersize=15,alpha=1)




m.drawmapboundary(fill_color='#FFFFFF')
#m.bluemarble()
#plt.title('Quick basemap example')
plt.title('Geoplot')
plt.show()

# %% [markdown]
# Analysis: There were earthquake on etreme costals of world...but minimal in south aftrica but more in west of US and in costal china towards east...we may dig into analysis on these regions to find the reasons of higher earthquakes in US coast and china coast but less in africa
