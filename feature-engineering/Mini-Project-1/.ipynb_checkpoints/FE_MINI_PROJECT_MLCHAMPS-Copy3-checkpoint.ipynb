# %% [markdown]
# #                                 Mini Project on Web Scraping

# %% [markdown]
# Group Name: ML CHAMPS
#
#     Group Members: G Shilpa (2019AIML580), Ram Sharma (2019AIML622), Sree Ram (2019AIML576)

# %% [markdown]
# Web Scrapping:
#
# Web scraping, web harvesting, or web data extraction is data scraping used for extracting data from websites. Web scraping may access the World Wide Web directly using the Hypertext Transfer Protocol, or through a web browser. It is a form of copying, in which specific data is gathered and copied from the web, typically into a central local database or spreadsheet, for later retrieval or analysis.

# %% [markdown]
# The four tasks that will be done as a part of this mini project is follows:
#
#     A. Data Acquisition
#     B. Data Cleaning
#     C. Data Integration
#     D. Exploratory Data Analysis and Recommendation

# %% [markdown]
# ## Data Science Project Lifecycle

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Data Acquisition - involves acquiring data from both internal and external sources, including social media or web scraping. In a steady state, data extraction and transfer routines would be in place, and new sources, once identified would be acquired following the established processes.

# %% [markdown]
# Data preparation - Usually referred to as "data wrangling", this step involves cleaning the data and reshaping it into a readily usable form for performing data science. This is similar to the traditional ETL steps in data warehousing in certain aspects, but involves more exploratory analysis and is primarily aimed at extracting features in usable formats.

# %% [markdown]
# Hypothesis and modeling are the traditional data mining steps - however in a data science project, these are not limited to statistical samples. Indeed the idea is to apply machine learning techniques to all data. A key sub-step is performed here for model selection. This involves the separation of a training set for training the candidate machine-learning models, and validation sets and test sets for comparing model performances and selecting the best performing model, gauging model accuracy and preventing over-fitting.
#
# Steps 2 through 4 are repeated a number of times as needed; as the understanding of data and business becomes clearer and results from initial models and hypotheses are evaluated, further tweaks are performed. These may sometimes include Step 5 (deployment) and be performed in a pre-production or "limited" / "pilot" environment before the actual full-scale "production" deployment, or could include fast-tweaks after deployment, based on the continuous deployment model.
# Once the model has been deployed in production, it is time for regular maintenance and operations. This operations phase could also follow a target DevOps model which gels well with the continuous deployment model, given the rapid time-to-market requirements in big data projects. Ideally, the deployment includes performance tests to measure model performance, and can trigger alerts when the model performance degrades beyond a certain acceptable threshold.

# %% [markdown]
# The optimization phase is the final step in the data science project life-cycle. This could be triggered by failing performance, or due to the need to add new data sources and retraining the model, or even to deploy improved versions of the model based on better algorithms

# %% [markdown]
# ## (A)	DATA ACQUISITION and  (B) DATA CLEANING

# %% [raw]
# (A) YOU AS TEAM OF THREE OR FOUR STUDENTS HAS TO ACQUIRE THE DATA FROM THREE OR FOUR ECOMMERCE PLATFORMS USING THE TECHNIQUE OF WEB SCRAPPING.
# FURTHER ON YOU CAN CONCENTRATE YOUR SEARCH BASED ON SOME OF THE CATEGORIES OF PRODUCTS LIKE VEGETABLES/FRUITS, GROCERY ITEMS, BRANDED ITEMS ETC.
# OUTCOME OF THIS STEP WILL BE THREE OR FOUR DIFFERENT DATA SETS EACH ONE BELONGING TO ONE PLATFORM.
# DOCUMENT ALL YOUR EFFORTS APPROPRIATELY IN THE JUPYTER NOTEBOOKS WITH DESCRIPTION AND CODE.
# THE WEIGTAGE FOR THIS TASK WILL BE 15 MARKS
#
# (B)	THE THREE OR FOUR DATASETS YOU HAVE GATHERED MIGHT HAVE SOME QUALITY ISSUES IN THEM LIKE (BUT NOT LIMITED TO) MISSING VALUES, DUPLICATE RECORDS, AND DERIVED ATTRIBUTES.
# YOU HAVE TO CLEANSE YOUR DATASETS TO REMOVE ALL SUCH DAUNTING ISSSUES.
# NARRATE ALL THE ISSUES WHICH YOU ENCOUNTER DURING THIS EXERCISE CLEARLY WITH APPROPRIATE EXPLANATION AND CODE.
# THE WEIGTAGE FOR THIS TASK WILL BE 5 MARKS.

# %% [markdown]
# e-commerce platforms Chosen are:
#      >Following platforms have been chosen for scrapping
#      - Big Basket (G Shilpa)
#      - Jio Mart (Ram Sharma)
#      - Amazon (sri Ram)

# %% [markdown]
# Member 1: G Shilpa Id: 2019AIML580 ECommerce Website: Big Basket

# %% [markdown]
# First step is to import the neccessary libraries used in python

# %%
# scraping of Big Basket
import pandas as pd
from datetime import datetime
import re
import json
import io
import requests
from bs4 import BeautifulSoup 
import numpy as np
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Below are the methods created for scraping the data from Big Basket

# %%
# this method returns json object of complete product list of Big Basket e-commerce website
def webscrapBigBasket(url):
    res = requests.get(url)
    data = json.loads(res.text)
    data = data['tab_info']['product_map']['all']['prods'] 
    data_len = len(data)
    return data

#Below method reads the json objects and extract the data required for this project
def readBBJson(jsonObj,category,filename):
    #print(jsonObj)
    data_len = len(jsonObj)
    #print(data_len)
    #data1 = "[]"
    #data2 = "[]"
    #data3 = "[]"
    for m in range (data_len):
              data1 = jsonObj[m]
              #print(data1)
              data2 = data1['all_prods']
              #scrap_record = ""
              if (len(data2)< 1):
                    sku = data1['sku'] 
                    name = data1['p_desc']
                    name = name.replace(', ', '') 
                    manufacturer = data1['p_brand']
                    weight = data1['w']
                    mrp = data1['mrp']
                    sp = data1['sp']
                    offer = data1['dis_val']
                    vendor ='BigBasket'
                    scrap_record = str(name)+','+str(weight)+','+mrp+','+sp+','+str(vendor)+','+str(category)+'\n'
                    #print(scrap_record)
                    with io.open(filename,'a',encoding ='utf8') as f2:
                        f2.write(scrap_record)
                        f2.close()
              else:
                for k in range(len(data2)):
                    data3 = data2[k]
                    sku = data3['sku'] 
                    name = data3['p_desc']
                    name = name.replace(', ', '') 
                    manufacturer = data3['p_brand']
                    weight = data3['w']
                    mrp = data3['mrp']
                    sp = data3['sp']
                    offer = data3['dis_val']
                    vendor ='BigBasket'
                    scrap_record = '"'+str(name)+'"'+','+str(weight)+','+mrp+','+sp+','+str(vendor)+','+str(category)+'\n'
                    #print(scrap_record)
                    with io.open(filename,'a',encoding ='utf8') as f2:
                        f2.write(scrap_record)
                        f2.close()

# %%
# Fruits and Vegitables
with io.open('bbfruits.csv','w', encoding ='utf8') as f1:
    f1.write('Product_Name,Product_Quantity,MRP_Price,Offer_Price,Vendor,Category'+'\n')
    f1.close()

i = 1
while (i < 4):
    i=i+1
    url = 'https://www.bigbasket.com/product/get-products/?slug=fruits-vegetables&page='+str(i)+'&tab_type=["all"]&sorted_on=popularity&listtype=pc'
    #jsonObj = webscrapBigBasket('https://www.bigbasket.com/product/get-products/?slug=fruits-vegetables&page=2&tab_type=["all"]&sorted_on=popularity&listtype=pc')
    jsonObj = webscrapBigBasket(url)
    filename = 'bbfruits.csv'
    readBBJson(jsonObj,'FruitsAndVegitables',filename)

# %%
bbfruits = pd.read_csv('bbfruits.csv')
bbfruits.head(10)
# Out:
#                               Product_Name Product_Quantity  MRP_Price  \
# 0                                  Cabbage             1 pc      23.75
# 1                    Ridge Gourd/Beerakaya            500 g      37.50
# 2                    Ridge Gourd/Beerakaya             1 kg      73.75
# 3              Coriander Leaves/Kothimeera            100 g      37.50
# 4              Coriander Leaves/Kothimeera            250 g      93.75
# 5              Coriander Leaves/Kothimeera             1 kg     373.75
# 6                        Mosambi - Economy             3 kg     123.75
# 7        Muskmelon - Netted Small/Kharbuja             1 pc      53.75
# 8  Apple - Red Delicious/WashingtonRegular            4 pcs     198.75
# 9                                 Beetroot            500 g      27.50
#
#    Offer_Price     Vendor             Category
# 0         19.0  BigBasket  FruitsAndVegitables
# 1         30.0  BigBasket  FruitsAndVegitables
# 2         59.0  BigBasket  FruitsAndVegitables
# 3         30.0  BigBasket  FruitsAndVegitables
# 4         75.0  BigBasket  FruitsAndVegitables
# 5        299.0  BigBasket  FruitsAndVegitables
# 6         99.0  BigBasket  FruitsAndVegitables
# 7         43.0  BigBasket  FruitsAndVegitables
# 8        159.0  BigBasket  FruitsAndVegitables
# 9         22.0  BigBasket  FruitsAndVegitables

# %%
# dals and pulses
with io.open('bbdals.csv','w', encoding ='utf8') as f1:
    f1.write('Product_Name,Product_Quantity,MRP_Price,Offer_Price,Vendor,Category'+'\n')
    f1.close()

i = 1
while (i < 4):
    i=i+1
    url = 'https://www.bigbasket.com/product/get-products/?slug=dals-pulses&page='+str(i)+'&tab_type=["all"]&sorted_on=popularity&listtype=pc'
    jsonObj = webscrapBigBasket(url)
    #print(jsonObj1)
    filename = 'bbdals.csv'
    readBBJson(jsonObj,'DalsAndPulses',filename)

# %%
bbdals = pd.read_csv('bbdals.csv')
bbdals.head(10)
# Out:
#                                         Product_Name Product_Quantity  \
# 0  bb Royal Idli Rice 5kg + Gota Urad 1kg + Raw P...            Combo
# 1                                        Soya Chunks            500 g
# 2                                      Soya - Chunks            200 g
# 3                 Organic - Brown Chana/Channa Brown             1 kg
# 4                    Organic - Brown Chana / Sengalu            500 g
# 5                   Organic - Brown Channa / Sengalu            200 g
# 6                 Organic - Brown Chana/Channa Brown             2 kg
# 7                                     Channa - Brown             1 kg
# 8                                     Channa - Brown            200 g
# 9                                     Channa - Brown            500 g
#
#    MRP_Price  Offer_Price     Vendor       Category
# 0      615.0        453.0  BigBasket  DalsAndPulses
# 1       70.0         68.0  BigBasket  DalsAndPulses
# 2       32.0         30.0  BigBasket  DalsAndPulses
# 3      160.0        110.0  BigBasket  DalsAndPulses
# 4       82.0         58.0  BigBasket  DalsAndPulses
# 5       32.0         24.0  BigBasket  DalsAndPulses
# 6      319.0        219.0  BigBasket  DalsAndPulses
# 7      140.0         78.0  BigBasket  DalsAndPulses
# 8       30.0         17.0  BigBasket  DalsAndPulses
# 9       70.0         42.0  BigBasket  DalsAndPulses

# %%
#Biscuits and cookies
with io.open('bbbiscuits.csv','w', encoding ='utf8') as f1:
    f1.write('Product_Name,Product_Quantity,MRP_Price,Offer_Price,Vendor,Category'+'\n')
    f1.close()

i = 1
while (i < 4):
    i=i+1
    url = 'https://www.bigbasket.com/product/get-products/?slug=biscuits-cookies&page='+str(i)+'&tab_type=["all"]&sorted_on=popularity&listtype=pc'
    jsonObj = webscrapBigBasket(url)
    #print(jsonObj1)
    filename = 'bbbiscuits.csv'
    readBBJson(jsonObj,'BiscuitsAndCookies',filename)

# %%
bbbiscuits = pd.read_csv('bbbiscuits.csv')
bbbiscuits.head(10)
# Out:
#                                     Product_Name Product_Quantity  MRP_Price  \
# 0  Moms Magic Cookies - Cashew & Almond Biscuits             60 g       10.0
# 1                               Biscuits - Chand            400 g      160.0
# 2                        Good Day Butter Cookies             75 g       10.0
# 3   Kitkat Mini 2 Finger Chocolate Covered Wafer           13.2 g       10.0
# 4    Kitkat 2 Finger Chocolate Covered Wafer Bar             18 g       15.0
# 5                     Good Day Chocochip Cookies             56 g       10.0
# 6                Hide & Seek Caffe Mocha Cookies            120 g       28.0
# 7                             Digestive Biscuits            100 g       20.0
# 8                        Treat - Orange Biscuits           6x60 g       60.0
# 9                    Treat Orange Cream Biscuits             60 g       10.0
#
#    Offer_Price     Vendor            Category
# 0         10.0  BigBasket  BiscuitsAndCookies
# 1        160.0  BigBasket  BiscuitsAndCookies
# 2         10.0  BigBasket  BiscuitsAndCookies
# 3         10.0  BigBasket  BiscuitsAndCookies
# 4         15.0  BigBasket  BiscuitsAndCookies
# 5         10.0  BigBasket  BiscuitsAndCookies
# 6         28.0  BigBasket  BiscuitsAndCookies
# 7         20.0  BigBasket  BiscuitsAndCookies
# 8         60.0  BigBasket  BiscuitsAndCookies
# 9         10.0  BigBasket  BiscuitsAndCookies

# %%
#Bath and handwash
with io.open('bbhandwash.csv','w', encoding ='utf8') as f1:
    f1.write('Product_Name,Product_Quantity,MRP_Price,Offer_Price,Vendor,Category'+'\n')
    f1.close()

i = 1
while (i < 4):
    i=i+1
    url = 'https://www.bigbasket.com/product/get-products/?slug=bath-hand-wash&page='+str(i)+'&tab_type=["all"]&sorted_on=popularity&listtype=pc'
    jsonObj = webscrapBigBasket(url)
    #print(jsonObj1)
    filename = 'bbhandwash.csv'
    readBBJson(jsonObj,'BathAndHandWash',filename)

# %%
bbhandwash = pd.read_csv('bbhandwash.csv')
bbhandwash.head(10)
# Out:
#                                         Product_Name Product_Quantity  \
# 0                        Bathing Soap - Soft & Fresh            125 g
# 1                 Hand Wash Liquid Refill - Skincare           900 ml
# 2                      Anti-Bacterial Hand Sanitiser           200 ml
# 3                      Anti-Bacterial Hand Sanitiser              5 L
# 4                      Anti-Bacterial Hand Sanitizer            50 ml
# 5                      Anti-Bacterial Hand Sanitizer           100 ml
# 6  Masterblaster Germ Protection Liquid Handwash ...            1.5 L
# 7          Bathing Soap - Ayurvedic Classic 18 Herbs            125 g
# 8                                     Hand Sanitizer           100 ml
# 9                                     Hand Sanitizer            60 ml
#
#    MRP_Price  Offer_Price     Vendor         Category
# 0      180.0       141.75  BigBasket  BathAndHandWash
# 1      149.0       149.00  BigBasket  BathAndHandWash
# 2      100.0        96.00  BigBasket  BathAndHandWash
# 3     2500.0      2250.00  BigBasket  BathAndHandWash
# 4       25.0        24.00  BigBasket  BathAndHandWash
# 5       50.0        48.00  BigBasket  BathAndHandWash
# 6      220.0       187.00  BigBasket  BathAndHandWash
# 7      105.0       105.00  BigBasket  BathAndHandWash
# 8       50.0        50.00  BigBasket  BathAndHandWash
# 9       30.0        30.00  BigBasket  BathAndHandWash

# %% [markdown]
# Merging all the Big Basket products

# %%
bbdf = pd.concat([bbfruits,bbdals,bbbiscuits, bbhandwash], ignore_index=True)
#df = pd.concat([dataset, dataset1,dataset2])

# %% [markdown]
# ### (B)	DATA CLEANING

# %%
# checking whether duplicate data exists
bbdf[bbdf.duplicated(['Product_Name'])]
# Out:
#                               Product_Name Product_Quantity  MRP_Price  \
# 2                    Ridge Gourd/Beerakaya             1 kg      73.75
# 4              Coriander Leaves/Kothimeera            250 g      93.75
# 5              Coriander Leaves/Kothimeera             1 kg     373.75
# 10                                Beetroot            250 g      13.75
# 12               Cucumber - English/Kheera            500 g      32.50
# ..                                     ...              ...        ...
# 402  Shower Gel - Pure Impact Body WashMen           500 ml     349.00
# 409     Hand Wash - Nature Germ Protection           750 ml     119.00
# 413                          Original Soap             75 g     128.00
# 414              Dreamflower Fragrant Talc             50 g      45.00
# 415              Dreamflower Fragrant Talc            200 g     180.00
#
#      Offer_Price     Vendor             Category
# 2           59.0  BigBasket  FruitsAndVegitables
# 4           75.0  BigBasket  FruitsAndVegitables
# 5          299.0  BigBasket  FruitsAndVegitables
# 10          11.0  BigBasket  FruitsAndVegitables
# 12          26.0  BigBasket  FruitsAndVegitables
# ..           ...        ...                  ...
# 402        279.2  BigBasket      BathAndHandWash
# 409         99.0  BigBasket      BathAndHandWash
# 413        128.0  BigBasket      BathAndHandWash
# 414         45.0  BigBasket      BathAndHandWash
# 415        180.0  BigBasket      BathAndHandWash
#
# [132 rows x 6 columns]

# %%
# removing duplicate data fromt he bb dataset bbdf.
bbdf.drop_duplicates(subset ="Product_Name", keep = 'first', inplace = True)

# %%
bbdf.tail(5)
# Out:
#                                           Product_Name Product_Quantity  \
# 410                               Ponds Starlight Talc            100 g
# 411                        Deeply Nourishing Body Wash           190 ml
# 412                   Shower Gel - AromaAbsolute Relax           750 ml
# 416                             Ayurveda Handmade Soap            125 g
# 417  Ayurveda Handmade Soap Pack of 3 - Get 75 gm Free          2x125 g
#
#      MRP_Price  Offer_Price     Vendor         Category
# 410       99.0        99.00  BigBasket  BathAndHandWash
# 411      115.0       115.00  BigBasket  BathAndHandWash
# 412      380.0       323.00  BigBasket  BathAndHandWash
# 416      129.0       118.68  BigBasket  BathAndHandWash
# 417      258.0       225.49  BigBasket  BathAndHandWash

# %%
# Checking the length of the data set
len(bbdf)
# Out:
# 286

# %% [markdown]
# below are the few of the observations from the big basket data set are

# %%
# Check the data types of the dataset bbdf
bbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 286 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_Name      286 non-null    object
#  1   Product_Quantity  286 non-null    object
#  2   MRP_Price         286 non-null    float64
#  3   Offer_Price       286 non-null    float64
#  4   Vendor            286 non-null    object
#  5   Category          286 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 15.6+ KB

# %%
bbdf.tail(10)
# Out:
#                                           Product_Name Product_Quantity  \
# 404  Gel Bathing Bar - Multi Variant (Buy 4 & Get 1...          2x625 g
# 405                    Gel Bathing Bar - Multi Variant            125 g
# 406             Cool Bath Soap - 99.9% Germ Protection            100 g
# 407       Yuzu Citrus Body Wash & Shower Gel - Refresh           250 ml
# 408                 Hand Wash - Nature Germ Protection         2x750 ml
# 410                               Ponds Starlight Talc            100 g
# 411                        Deeply Nourishing Body Wash           190 ml
# 412                   Shower Gel - AromaAbsolute Relax           750 ml
# 416                             Ayurveda Handmade Soap            125 g
# 417  Ayurveda Handmade Soap Pack of 3 - Get 75 gm Free          2x125 g
#
#      MRP_Price  Offer_Price     Vendor         Category
# 404      480.0       480.00  BigBasket  BathAndHandWash
# 405      240.0       240.00  BigBasket  BathAndHandWash
# 406      280.0       246.40  BigBasket  BathAndHandWash
# 407      200.0       160.00  BigBasket  BathAndHandWash
# 408      238.0       198.00  BigBasket  BathAndHandWash
# 410       99.0        99.00  BigBasket  BathAndHandWash
# 411      115.0       115.00  BigBasket  BathAndHandWash
# 412      380.0       323.00  BigBasket  BathAndHandWash
# 416      129.0       118.68  BigBasket  BathAndHandWash
# 417      258.0       225.49  BigBasket  BathAndHandWash

# %%
bbdf.groupby(['Category','Product_Name']).sum()
# Out:
#                                                                         MRP_Price  \
# Category            Product_Name
# BathAndHandWash     Almond & Rose Soap                                      30.00
#                     Anti-Bacterial Hand Sanitiser                          100.00
#                     Anti-Bacterial Hand Sanitizer                           25.00
#                     Antibacterial Hand Sanitizer - 72% Alcohol Base...     250.00
#                     Ayurveda Handmade Soap                                 129.00
# ...                                                                           ...
# FruitsAndVegitables Ridge Gourd/Beerakaya                                   37.50
#                     Snake Gourd/Potlakaya                                   25.00
#                     Sweet Potato/Chilakada Dumpa                            31.25
#                     Tomato - Hybrid/Bengaluru Tamata                        31.25
#                     Totapuri Mango                                          68.75
#
#                                                                         Offer_Price
# Category            Product_Name
# BathAndHandWash     Almond & Rose Soap                                        30.00
#                     Anti-Bacterial Hand Sanitiser                             96.00
#                     Anti-Bacterial Hand Sanitizer                             24.00
#                     Antibacterial Hand Sanitizer - 72% Alcohol Base...       250.00
#                     Ayurveda Handmade Soap                                   118.68
# ...                                                                             ...
# FruitsAndVegitables Ridge Gourd/Beerakaya                                     30.00
#                     Snake Gourd/Potlakaya                                     20.00
#                     Sweet Potato/Chilakada Dumpa                              25.00
#                     Tomato - Hybrid/Bengaluru Tamata                          25.00
#                     Totapuri Mango                                            55.00
#
# [286 rows x 2 columns]

# %%
# product quatity has the measure string appended to it. separating the quantity and measure columns
#bbdf['quantity']=bbdf['Product_Quantity']

# %%
bbdf[['Product_Quantity','Qty_Unit']] = bbdf.Product_Quantity.str.split(expand=True)

# %%
bbdf.tail(20)
# Out:
#                                           Product_Name Product_Quantity  \
# 391                       Bathing Soap - Almond & Rose             4x75
# 392                                      Original Soap              125
# 393       Shower Gel - Frangipani & Oil Body WashWomen              250
# 394                       Bathing Soap - Original Neem              100
# 395                           Bathing Soap - Ayurvedic               70
# 396  Soap Bar-Lemon & Tea Tree Oil+Cooling Mint Soa...            Combo
# 397                      Multani Mitti - Body Cleanser             4x75
# 399                                   Hand Wash - Mild              215
# 401              Shower Gel - Pure Impact Body WashMen              250
# 403             Shower Gel - Active Clean Body WashMen              250
# 404  Gel Bathing Bar - Multi Variant (Buy 4 & Get 1...            2x625
# 405                    Gel Bathing Bar - Multi Variant              125
# 406             Cool Bath Soap - 99.9% Germ Protection              100
# 407       Yuzu Citrus Body Wash & Shower Gel - Refresh              250
# 408                 Hand Wash - Nature Germ Protection            2x750
# 410                               Ponds Starlight Talc              100
# 411                        Deeply Nourishing Body Wash              190
# 412                   Shower Gel - AromaAbsolute Relax              750
# 416                             Ayurveda Handmade Soap              125
# 417  Ayurveda Handmade Soap Pack of 3 - Get 75 gm Free            2x125
#
#      MRP_Price  Offer_Price     Vendor         Category Qty_Unit
# 391      120.0       120.00  BigBasket  BathAndHandWash        g
# 392      200.0       200.00  BigBasket  BathAndHandWash        g
# 393      199.0       169.15  BigBasket  BathAndHandWash       ml
# 394      120.0       120.00  BigBasket  BathAndHandWash        g
# 395      111.0        98.79  BigBasket  BathAndHandWash        g
# 396      184.0       184.00  BigBasket  BathAndHandWash     None
# 397      140.0       140.00  BigBasket  BathAndHandWash        g
# 399       99.0        99.00  BigBasket  BathAndHandWash       ml
# 401      199.0       175.12  BigBasket  BathAndHandWash       ml
# 403      199.0       169.15  BigBasket  BathAndHandWash       ml
# 404      480.0       480.00  BigBasket  BathAndHandWash        g
# 405      240.0       240.00  BigBasket  BathAndHandWash        g
# 406      280.0       246.40  BigBasket  BathAndHandWash        g
# 407      200.0       160.00  BigBasket  BathAndHandWash       ml
# 408      238.0       198.00  BigBasket  BathAndHandWash       ml
# 410       99.0        99.00  BigBasket  BathAndHandWash        g
# 411      115.0       115.00  BigBasket  BathAndHandWash       ml
# 412      380.0       323.00  BigBasket  BathAndHandWash       ml
# 416      129.0       118.68  BigBasket  BathAndHandWash        g
# 417      258.0       225.49  BigBasket  BathAndHandWash        g

# %% [markdown]
# ### Data Scraping from Jio Mart

# %% [markdown]
# Member 2: Ram Sharma Id: 2019AIML622 ECommerce Website: Jio Mart

# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import pandas as pd

# %%
# utility to print any error passed
def log_error(e):
    print(e)

# %%
# check if the response returned is good or not
def is_good_response(resp):
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 and content_type is not None and content_type.find('html') > -1)

# %%
# utility to get html content from a given url
def simple_get(url):
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else :
                return None
    except RequestException as re:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None

# %%
# JioMart data scraping - Dals and Pulses

raw_html_dp = simple_get('https://www.jiomart.com/category/staples/dals-pulses')

# get html parsed using Beautiful soup
html_soup = BeautifulSoup(raw_html_dp, 'html.parser')

# print(html_soup)

# %%
containers = html_soup.findAll("div", {"class" : "col-md-3 p-0"})
# print (BeautifulSoup.prettify(containers[0]))

# %%
ProductNamesList = []
ProductQtyList = []
MRP_List = []
Offer_Price_List = []
Vendor_List = []
Category_List = []
Qty_Unit_List = []

for container in containers:
    product = container.div.img["alt"]
    ProductNamesList.append(product)
    
    price_container = container.findAll("strike", {"id" : "price"})
    price = price_container[0].text.strip()
    MRP_List.append(price)
    
    final_price_container = container.findAll("span", {"id" : "final_price"})
    final_price = final_price_container[0].text.strip()
    Offer_Price_List.append(final_price)
    
    #print ("Product:" + product)
    #print ("Price:" + price)
    #print ("Final Price:" + final_price)
    
    Vendor_List.append('JioMart')
    Category_List.append('DalAndPulses')
    Qty_Unit_List.append('Kg')
    
#     print (product + "," + price + "," + final_price + ",JioMart" + ",Dals-Vegetables" +"\n")
#     f.write(product + "," + price + "," + final_price + ",JioMart" + ",Dals-Vegetables" +"\n")

    
# print('ProductNamesList =>', ProductNamesList)
# print('MRP_List =>', MRP_List)
# print('Offer_Price_List =>', Offer_Price_List)
# print('Vendor_List =>', Vendor_List)
# print('Category_List =>', Category_List)

# f.close()

# %%
import pandas as pd

table_dict = { 'Product_Name' : ProductNamesList,
                'MRP_Price' : MRP_List,
                'Offer_Price' : Offer_Price_List,
                'Vendor' : Vendor_List,
                'Category' : Category_List,
                'Qty_Unit' : Qty_Unit_List}

jmdf = pd.DataFrame(table_dict)

jmdf.head()
# Out:
#                        Product_Name MRP_Price Offer_Price   Vendor  \
# 0         Good Life Rajma Red 500 g   ₹ 68.00     ₹ 60.00  JioMart
# 1           Good Life Dal Mix 500 g   ₹ 76.00     ₹ 65.00  JioMart
# 2  Good Life Urad Washed Gota 500 g   ₹ 83.00     ₹ 73.00  JioMart
# 3            Good Life Tur Dal 1 kg  ₹ 138.00    ₹ 115.00  JioMart
# 4       Tip Top Roasted Chana 200 g   ₹ 44.00     ₹ 37.40  JioMart
#
#        Category Qty_Unit
# 0  DalAndPulses       Kg
# 1  DalAndPulses       Kg
# 2  DalAndPulses       Kg
# 3  DalAndPulses       Kg
# 4  DalAndPulses       Kg

# %%
price_qty_mixed=jmdf.Product_Name.str.split(expand=True,)
print(price_qty_mixed)
print(type(price_qty_mixed))
# Out:
#        0        1        2         3           4     5     6      7     8  \
# 0   Good     Life    Rajma       Red         500     g  None   None  None
# 1   Good     Life      Dal       Mix         500     g  None   None  None
# 2   Good     Life     Urad    Washed        Gota   500     g   None  None
# 3   Good     Life      Tur       Dal           1    kg  None   None  None
# 4    Tip      Top  Roasted     Chana         200     g  None   None  None
# 5     24   Mantra  Organic     Chana         Dal   500     g   None  None
# 6     24   Mantra  Organic     Brown       Chana   500     g   None  None
# 7   Good     Life    Rajma  Sharmili         500     g  None   None  None
# 8   Good     Life     Urad     Whole         500     g  None   None  None
# 9     24   Mantra  Organic     Moong       Whole   500     g   None  None
# 10  Good     Life     Urad       Dal      Chilka     1    kg   None  None
# 11    24   Mantra  Organic    Masoor         Dal   500     g   None  None
# 12  Good     Life     Urad       Dal      Chilka   500     g   None  None
# 13  Good     Life  Roasted   Skinned      Bengal  Gram   200      g  None
# 14  Good     Life   Masoor       Dal           1    kg  None   None  None
# 15  Good     Life  Roasted      Skin      Bengal     g   500      g  None
# 16  Good     Life   Kabuli     Chana           1    kg  None   None  None
# 17  Tata  Sampann     High   Protein  Unpolished   Tur     /  Arhar   Dal
# 18   Tip      Top    Moong       Dal         500     g  None   None  None
# 19   Tip      Top    Moong    Chilka         500     g  None   None  None
#
#        9    10
# 0   None  None
# 1   None  None
# 2   None  None
# 3   None  None
# 4   None  None
# 5   None  None
# 6   None  None
# 7   None  None
# 8   None  None
# 9   None  None
# 10  None  None
# 11  None  None
# 12  None  None
# 13  None  None
# 14  None  None
# 15  None  None
# 16  None  None
# 17     1    kg
# 18  None  None
# 19  None  None
# <class 'pandas.core.frame.DataFrame'>

# %%
qty_df = jmdf.Product_Name.str.extract('(\d+)')

jmdf['Product_Quantity'] = qty_df

# %%
jmdf['Product_Name'] = jmdf['Product_Name'].str[:16]

# %%
import numpy as np

newdf = jmdf[['Product_Name', 'Product_Quantity', 'MRP_Price', 'Offer_Price', 'Vendor', 'Category', 'Qty_Unit']].copy()

newdf['Product_Quantity'] = pd.to_numeric(jmdf['Product_Quantity'])

# newdf['Product_Quantity'] = newdf['Product_Quantity'].filter().div(1000)

a = np.array(newdf['Product_Quantity'].values.tolist())
# print (a)

newdf['Product_Quantity'] = np.where(a > 100, a/1000, a).tolist()

newdf['MRP_Price'] = newdf['MRP_Price'].map(lambda x: x.lstrip('₹').strip())
newdf['Offer_Price'] = newdf['Offer_Price'].map(lambda x: x.lstrip('₹').strip())

newdf.head()
newdf.describe()

newdf['MRP_Price'] = pd.to_numeric(newdf['MRP_Price'])
newdf['Offer_Price'] = pd.to_numeric(newdf['Offer_Price'])

# %%
newdf.head()
# Out:
#        Product_Name  Product_Quantity  MRP_Price  Offer_Price   Vendor  \
# 0  Good Life Rajma                0.5       68.0         60.0  JioMart
# 1  Good Life Dal Mi               0.5       76.0         65.0  JioMart
# 2  Good Life Urad W               0.5       83.0         73.0  JioMart
# 3  Good Life Tur Da               1.0      138.0        115.0  JioMart
# 4  Tip Top Roasted                0.2       44.0         37.4  JioMart
#
#        Category Qty_Unit
# 0  DalAndPulses       Kg
# 1  DalAndPulses       Kg
# 2  DalAndPulses       Kg
# 3  DalAndPulses       Kg
# 4  DalAndPulses       Kg

# %% [markdown]
# Member 3: Sri Ram Hari Id: 2019AIML576 ECommerce Website: Amazon

# %%
import requests # required for HTTP requests: pip install requests
from bs4 import BeautifulSoup # required for HTML and XML parsing                                                              # required for HTML and XML parsing: pip install beautifulsoup4
import pandas as pd # required for getting the data in dataframes : pip install pandas
import time # to time the requests
from multiprocessing import Process, Queue, Pool
import threading
import sys

# %%
startTime = time.time()
qcount = 0 # the count in queue used to track the elements in queue
products=[] # List to store name of the product
prices=[] # List to store price of the product
ratings=[] # List to store ratings of the product
no_pages = 9 # no of pages to scrape in the website (provide it via arguments)

# %%
def scrap_amazon():
    fruits_1 ="Fruits|https://www.amazon.in/s?i=grocery&rh=n%3A4859730031&brr=1&qid=1590908038&rd=1&ref=sr_pg_1"
    fruits_2 = "Fruits|https://www.amazon.in/s?i=grocery&rh=n%3A4859730031&page=2&brr=1&qid=1590923241&rd=1&ref=sr_pg_2"
    fruits_3 ="Fruits|https://www.amazon.in/s?i=grocery&rh=n%3A4859730031&page=3&brr=1&qid=1590923274&rd=1&ref=sr_pg_3"
    veg_1 ="Vegtables|https://www.amazon.in/s?i=grocery&rh=n%3A4859731031&brr=1&qid=1590923340&rd=1&ref=sr_pg_1"
    veg_2 ="Vegtables|https://www.amazon.in/s?i=grocery&rh=n%3A4859731031&page=2&brr=1&qid=1590923340&rd=1&ref=sr_pg_2"
    veg_3 ="Vegtables|https://www.amazon.in/s?i=grocery&rh=n%3A4859731031&page=3&brr=1&qid=1590923377&rd=1&ref=sr_pg_3"
    pulses_1 = "Pulses|https://www.amazon.in/Dals-Pulses-Indian-Rice-Flour/s?i=grocery&rh=n%3A4859614031%2Cp_n_cuisinebin%3A4868228031&qid=1590919781&ref=sr_pg_1"
    pulses_2 = "Pulses|https://www.amazon.in/Dals-Pulses-Indian-Rice-Flour/s?i=grocery&rh=n%3A4859614031%2Cp_n_cuisinebin%3A4868228031&page=2&qid=1590923434&ref=sr_pg_2"
    pulses_3 = "Pulses|https://www.amazon.in/Dals-Pulses-Indian-Rice-Flour/s?i=grocery&rh=n%3A4859614031%2Cp_n_cuisinebin%3A4868228031&page=3&qid=1590923443&ref=sr_pg_3" 
    count  = 0
    data =[]
    urlInfos = [fruits_1, fruits_2, fruits_3, veg_1, veg_2, veg_3, pulses_1, pulses_2, pulses_3]
    for info in urlInfos:
        category, url = info.split("|")
        headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate",     "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
        r = requests.get(url, headers=headers)
        content = r.content
        soup = BeautifulSoup(content)
        for d in soup.findAll('div', attrs={'class':'a-section a-spacing-medium'}):
            temp_list =[]
            name = d.find('span', attrs={'class':'a-size-base-plus a-color-base a-text-normal'})
            price = d.find('span', attrs={'class':'a-price-whole'})
            mrp = extract_mrp(d)
            rating = d.find('span', attrs={'class':'a-icon-alt'})
            temp_list.append(text(name))
            temp_list.append(text(price))
            temp_list.append(mrp)
            temp_list.append(category)
            temp_list.append('Amazon')
            data.append(temp_list)
    return data 

def text(data):
    return data.text if data is not None else None
    
def extract_rating(data):
    return data.replace("out of 5 stars", "") if data is not None else None  
    
def extract_mrp(d):
    if d.find('span', attrs={'class':'a-price a-text-price'}) is not None and d.find('span', attrs={'class':'a-price a-text-price'}) \
                .find('span', attrs={'class':'a-offscreen'}) is not None:
        return text(d.find('span', attrs={'class':'a-price a-text-price'}) \
                .find('span', attrs={'class':'a-offscreen'})).replace("₹", "")
    else:
        return None
       
def extract_weight(d):
    if d is not None:
        pro = d.split(",")
        if(len(pro) > 1):
            return pro[1]
    else:
        return None
    
def extract_product_name(d):
    if d is not None:
        pro = d.split(",")
        if(len(pro) > 1):
            return pro[0]
    else:
        return 0

data = scrap_amazon()

# Create the pandas DataFrame  
amazon_df = pd.DataFrame(data, columns = ['Product', 'Offer_Price', 'MRP_Price', 'Category', 'Vendor'])

amazon_df['Product_Quantity'] = amazon_df['Product'].apply(lambda s: extract_weight(s))
amazon_df['Product_Name'] = amazon_df['Product'].apply(lambda s: extract_product_name(s))
amazon_df.drop(['Product'], axis=1, inplace=True)
amazon_df = amazon_df[['Product_Name', 'Product_Quantity', 'Offer_Price',  'MRP_Price', 'Category', 'Vendor']]
amazon_df = amazon_df[~amazon_df['Product_Quantity'].isnull()]
print(amazon_df)
# Out:
#                                           Product_Name  Product_Quantity  \
# 0                                   Fresh Shimla Apple          6 Pieces
# 1                  D'nature Fresh Natural Blue Berries          250 Gram
# 3                                 Fresh Banana Robusta             500 g
# 4                            Fresh Water Melon - Kiran              1 Pc
# 5                                         Fresh Papaya           1 Piece
# ..                                                 ...               ...
# 223  FARMUP Masoor Dal - 1 Kg (Unpolished) | High P...   Premium Quality
# 229               B&B Organics Brown Horse Gram Kulthi              3 KG
# 233                   Super Traders Express Toovar Dal             10 kg
# 241     Our Organik Tree Moong Dal Yellow/Split/Washed             800 g
# 243               B&B Organics Brown Horse Gram Kulthi             500 g
#
#     Offer_Price MRP_Price Category  Vendor
# 0           680      None   Fruits  Amazon
# 1           530       799   Fruits  Amazon
# 3            13        51   Fruits  Amazon
# 4            44        57   Fruits  Amazon
# 5           121      None   Fruits  Amazon
# ..          ...       ...      ...     ...
# 223         260       499   Pulses  Amazon
# 229        None      None   Pulses  Amazon
# 233       1,480     1,999   Pulses  Amazon
# 241         390       480   Pulses  Amazon
# 243        None      None   Pulses  Amazon
#
# [115 rows x 6 columns]

# %%
amazon_df.to_csv('amazon.csv', index=False,encoding='utf-8')

# %% [markdown]
# ## Clean Data

# %%
amazon_df = amazon_df.dropna()
amazon_df
# Out:
#                                           Product_Name  Product_Quantity  \
# 1                  D'nature Fresh Natural Blue Berries          250 Gram
# 3                                 Fresh Banana Robusta             500 g
# 4                            Fresh Water Melon - Kiran              1 Pc
# 7                                      Fresh Mango Raw             500 g
# 8                                        Fresh Mosambi          6 Pieces
# ..                                                 ...               ...
# 211               B&B Organics Brown Horse Gram Kulthi              1 KG
# 220  FARMUP Masoor Dal - 1 Kg (Unpolished) | High P...   Premium Quality
# 223  FARMUP Masoor Dal - 1 Kg (Unpolished) | High P...   Premium Quality
# 233                   Super Traders Express Toovar Dal             10 kg
# 241     Our Organik Tree Moong Dal Yellow/Split/Washed             800 g
#
#     Offer_Price MRP_Price Category  Vendor
# 1           530       799   Fruits  Amazon
# 3            13        51   Fruits  Amazon
# 4            44        57   Fruits  Amazon
# 7            50        60   Fruits  Amazon
# 8            42       231   Fruits  Amazon
# ..          ...       ...      ...     ...
# 211         287       359   Pulses  Amazon
# 220         260       499   Pulses  Amazon
# 223         260       499   Pulses  Amazon
# 233       1,480     1,999   Pulses  Amazon
# 241         390       480   Pulses  Amazon
#
# [74 rows x 6 columns]

# %%
amazon_df['Product_Quantity'] =  df.Product_Quantity.str.strip()

# %%
amazon_df
# Out:
#                                           Product_Name Product_Quantity  \
# 1                  D'nature Fresh Natural Blue Berries             1 kg
# 3                                 Fresh Banana Robusta             1 kg
# 4                            Fresh Water Melon - Kiran          500 gms
# 7                                      Fresh Mango Raw             1 kg
# 8                                        Fresh Mosambi          500 gms
# ..                                                 ...              ...
# 211               B&B Organics Brown Horse Gram Kulthi              NaN
# 220  FARMUP Masoor Dal - 1 Kg (Unpolished) | High P...              NaN
# 223  FARMUP Masoor Dal - 1 Kg (Unpolished) | High P...              NaN
# 233                   Super Traders Express Toovar Dal              NaN
# 241     Our Organik Tree Moong Dal Yellow/Split/Washed              NaN
#
#     Offer_Price MRP_Price Category  Vendor
# 1           530       799   Fruits  Amazon
# 3            13        51   Fruits  Amazon
# 4            44        57   Fruits  Amazon
# 7            50        60   Fruits  Amazon
# 8            42       231   Fruits  Amazon
# ..          ...       ...      ...     ...
# 211         287       359   Pulses  Amazon
# 220         260       499   Pulses  Amazon
# 223         260       499   Pulses  Amazon
# 233       1,480     1,999   Pulses  Amazon
# 241         390       480   Pulses  Amazon
#
# [74 rows x 6 columns]

# %%
amazon_df[['Product_Quantity','Qty_Unit']] = amazon_df.Product_Quantity.str.split(expand=True)

# %%
amazon_df = amazon_df.dropna()

# %%
#amazon_df['Qty_Unit'] = amazon_df.Qty_Unit.str.replace('grm','g')
amazon_df[ 'Qty_Unit' ] = amazon_df.Qty_Unit.str.replace('gms','g')
# Out:
# C:\Users\shilpa\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
amazon_df.to_csv('amazon.csv', index=False,encoding='utf-8')

# %%
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 1 to 39
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_Name      15 non-null     object
#  1   Product_Quantity  15 non-null     object
#  2   Offer_Price       15 non-null     object
#  3   MRP_Price         15 non-null     object
#  4   Category          15 non-null     object
#  5   Vendor            15 non-null     object
#  6   Qty_Unit          15 non-null     object
# dtypes: object(7)
# memory usage: 960.0+ bytes

# %%
amazon_df['MRP_Price'] = amazon_df.MRP_Price.str.replace('Rs', '').astype(float)
# Out:
# C:\Users\shilpa\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
amazon_df['Offer_Price'] = amazon_df.Offer_Price.str.replace('r', '').astype(float)
# Out:
# C:\Users\shilpa\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 1 to 39
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_Name      15 non-null     object
#  1   Product_Quantity  15 non-null     object
#  2   Offer_Price       15 non-null     float64
#  3   MRP_Price         15 non-null     float64
#  4   Category          15 non-null     object
#  5   Vendor            15 non-null     object
#  6   Qty_Unit          15 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 960.0+ bytes

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_Name      20 non-null     object
#  1   Product_Quantity  20 non-null     float64
#  2   MRP_Price         20 non-null     float64
#  3   Offer_Price       20 non-null     float64
#  4   Vendor            20 non-null     object
#  5   Category          20 non-null     object
#  6   Qty_Unit          20 non-null     object
# dtypes: float64(3), object(4)
# memory usage: 1.2+ KB

# %%
bbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 286 entries, 0 to 417
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_Name      286 non-null    object
#  1   Product_Quantity  286 non-null    object
#  2   MRP_Price         286 non-null    float64
#  3   Offer_Price       286 non-null    float64
#  4   Vendor            286 non-null    object
#  5   Category          286 non-null    object
#  6   Qty_Unit          280 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 17.9+ KB

# %% [markdown]
# # (C)	DATA INTEGRATION

# %% [markdown]
# BY THIS TIME YOU MUST HAVE CLEANSED DATA AVAILABLE WITH YOU. FOR FURTHER PROCESSING YOU NEED TO INTEGRATE ALL THESE DATASETS TOGETHER INTO A SINGLE DATASET.
# YOU MAY NEED TO DECIDE UPON A COMMON SCHEMA FOR THIS ACTIVITY WHICH CAN BE APPLIED ON THE ALL DATASETS. YOU MAY THINK OF ADDING OR DELETING OR MODIFYING THE ATTRIBUTES OF THE EXISTING DATASETS.
# CAPTURE ALL THE THINKING GONE BEHIND PREPARING SUCH A SINGLE DATABASE IN THE DESCRIPTIVE MANNER IN THE JUPYTER NOTEBOOK ALONG WITH THE CODE.
# THE WEIGTAGE FOR THIS TASK WILL BE 5 MARKS

# %% [markdown]
# Based on the datasets extracted from Big basket , Jio mart and Amazon, we would like to consider below columns for the common schema. we would like to use this common schema for further analysis and for the EDA
#
# Product_Name
#
# Product_Quantity
#
# MRP_price
#
# Offer_price
#
# Vendor
#
# Category

# %% [markdown]
# ### Mergin the Data Sets from different platforms

# %%
frames = [bbdf, newdf,amazon_df]

result = pd.concat(frames, axis=0, join='outer', ignore_index=False, keys=None,
          levels=None, names=None, verify_integrity=False, copy=True)

# result = df.append(newdf)

result.describe()
# Out:
#         MRP_Price  Offer_Price
# count  321.000000   321.000000
# mean   124.717445   103.627664
# std    125.019616    97.119672
# min      5.000000     4.000000
# 25%     36.250000    30.000000
# 50%     91.000000    78.000000
# 75%    180.000000   149.000000
# max    799.000000   560.000000

# %%
result
# Out:
#                                Product_Name Product_Quantity  MRP_Price  \
# 0                                   Cabbage                1      23.75
# 1                     Ridge Gourd/Beerakaya              500      37.50
# 3               Coriander Leaves/Kothimeera              100      37.50
# 6                         Mosambi - Economy                3     123.75
# 7         Muskmelon - Netted Small/Kharbuja                1      53.75
# ..                                      ...              ...        ...
# 31      D'nature Fresh Natural Blue Berries                1     799.00
# 36      D'nature Fresh Natural Blue Berries              500     799.00
# 37  Being Marwari Gota Dry Coconuts (Medium              500     300.00
# 38             Fresh Produce Mango - Malgoa              500     690.00
# 39                        Fresh Pomegranate                1     650.00
#
#     Offer_Price     Vendor             Category Qty_Unit
# 0          19.0  BigBasket  FruitsAndVegitables       pc
# 1          30.0  BigBasket  FruitsAndVegitables        g
# 3          30.0  BigBasket  FruitsAndVegitables        g
# 6          99.0  BigBasket  FruitsAndVegitables       kg
# 7          43.0  BigBasket  FruitsAndVegitables       pc
# ..          ...        ...                  ...      ...
# 31        530.0     Amazon               Fruits       kg
# 36        530.0     Amazon               Fruits        g
# 37        169.0     Amazon               Fruits        g
# 38        540.0     Amazon               Fruits        g
# 39        560.0     Amazon               Fruits       kg
#
# [321 rows x 7 columns]

# %%
result.head(100)
# Out:
#                                     Product_Name Product_Quantity  MRP_Price  \
# 0                                        Cabbage                1      23.75
# 1                          Ridge Gourd/Beerakaya              500      37.50
# 3                    Coriander Leaves/Kothimeera              100      37.50
# 6                              Mosambi - Economy                3     123.75
# 7              Muskmelon - Netted Small/Kharbuja                1      53.75
# ..                                           ...              ...        ...
# 148   Organic - Green Moong Whole / Pesara Pappu              500     110.00
# 149                  Organic - Green Moong Whole                2     295.00
# 151                  Organic Kabuli Chana/Channa                1     199.00
# 153  Organic - Kabuli Chana / Tella Muku Sengalu              500     100.00
# 154           Organic Little Millet - Samai Rice                1     149.00
#
#      Offer_Price     Vendor             Category Qty_Unit
# 0           19.0  BigBasket  FruitsAndVegitables       pc
# 1           30.0  BigBasket  FruitsAndVegitables        g
# 3           30.0  BigBasket  FruitsAndVegitables        g
# 6           99.0  BigBasket  FruitsAndVegitables       kg
# 7           43.0  BigBasket  FruitsAndVegitables       pc
# ..           ...        ...                  ...      ...
# 148         88.0  BigBasket        DalsAndPulses        g
# 149        295.0  BigBasket        DalsAndPulses       kg
# 151        133.0  BigBasket        DalsAndPulses       kg
# 153         69.0  BigBasket        DalsAndPulses        g
# 154        117.0  BigBasket        DalsAndPulses       kg
#
# [100 rows x 7 columns]

# %%
result.groupby(['Category','Product_Name']).sum()
# Out:
#                                                                         MRP_Price  \
# Category            Product_Name
# BathAndHandWash     Almond & Rose Soap                                      30.00
#                     Anti-Bacterial Hand Sanitiser                          100.00
#                     Anti-Bacterial Hand Sanitizer                           25.00
#                     Antibacterial Hand Sanitizer - 72% Alcohol Base...     250.00
#                     Ayurveda Handmade Soap                                 129.00
# ...                                                                           ...
# FruitsAndVegitables Ridge Gourd/Beerakaya                                   37.50
#                     Snake Gourd/Potlakaya                                   25.00
#                     Sweet Potato/Chilakada Dumpa                            31.25
#                     Tomato - Hybrid/Bengaluru Tamata                        31.25
#                     Totapuri Mango                                          68.75
#
#                                                                         Offer_Price
# Category            Product_Name
# BathAndHandWash     Almond & Rose Soap                                        30.00
#                     Anti-Bacterial Hand Sanitiser                             96.00
#                     Anti-Bacterial Hand Sanitizer                             24.00
#                     Antibacterial Hand Sanitizer - 72% Alcohol Base...       250.00
#                     Ayurveda Handmade Soap                                   118.68
# ...                                                                             ...
# FruitsAndVegitables Ridge Gourd/Beerakaya                                     30.00
#                     Snake Gourd/Potlakaya                                     20.00
#                     Sweet Potato/Chilakada Dumpa                              25.00
#                     Tomato - Hybrid/Bengaluru Tamata                          25.00
#                     Totapuri Mango                                            55.00
#
# [312 rows x 2 columns]

# %% [markdown]
# # (D) EDA (Exploratory Data Analysis) and RECOMMENDATION

# %% [raw]
# (D)	EXPLORATORY DATA ANALYSIS AND RECOMMENDATION
# USE THE EXPLORATORY DATA ANALYSIS TECHNIQUE ON THE DATASET IN ORDER TO FIND OUT THE INTERESTING INSIGHTS THAT ARE HIDDEN WITHIN THE DATA CAPTURED.
# NOW ASSUME THAT A CUSTOMER IS LOOKING FOR A PARTICULAR ITEM, THEN WITH HELP OF SIMPLE PROGRAM YOU SHOULD BE ABLE TO RECOMMEND THE ONLINE PLATFORM FROM WHICH HE SHOULD MAKE A PURCHASE OF THIS ITEM.
# DESCRIBE ALL EDA STEPS THOSE ARE DONE WITH THE OBSERVATIONS OBTAINED OUT OF IT WITH THE HELP OF PYTHON CODE IN JUPYTER NOTEBOOK.
# THE WEIGTAGE FOR THIS TASK WILL BE 5 MARKS.

# %% [markdown]
# The purpose of EDA is to find insights which will serve us for Data cleaning/preparation/transformation which will ultimately be used into a machine learning algorithm. We will proceed as follow: We use data analsyis and visulization at every step of the machine learning process. For the preparations lets first import the necessary libraries and load the files needed for our EDA

# %% [markdown]
# checking the type of the data

# %%
result.dtypes
# Out:
# Product_Name         object
# Product_Quantity     object
# MRP_Price           float64
# Offer_Price         float64
# Vendor               object
# Category             object
# Qty_Unit             object
# dtype: object

# %%
result.head()
# Out:
#                         Product_Name Product_Quantity  MRP_Price  Offer_Price  \
# 0                            Cabbage                1      23.75         19.0
# 1              Ridge Gourd/Beerakaya              500      37.50         30.0
# 3        Coriander Leaves/Kothimeera              100      37.50         30.0
# 6                  Mosambi - Economy                3     123.75         99.0
# 7  Muskmelon - Netted Small/Kharbuja                1      53.75         43.0
#
#       Vendor             Category Qty_Unit
# 0  BigBasket  FruitsAndVegitables       pc
# 1  BigBasket  FruitsAndVegitables        g
# 3  BigBasket  FruitsAndVegitables        g
# 6  BigBasket  FruitsAndVegitables       kg
# 7  BigBasket  FruitsAndVegitables       pc

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 321 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_Name      321 non-null    object
#  1   Product_Quantity  321 non-null    object
#  2   MRP_Price         321 non-null    float64
#  3   Offer_Price       321 non-null    float64
#  4   Vendor            321 non-null    object
#  5   Category          321 non-null    object
#  6   Qty_Unit          315 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 20.1+ KB

# %%
result.shape
# Out:
# (321, 7)

# %%
result.describe()
# Out:
#         MRP_Price  Offer_Price
# count  321.000000   321.000000
# mean   124.717445   103.627664
# std    125.019616    97.119672
# min      5.000000     4.000000
# 25%     36.250000    30.000000
# 50%     91.000000    78.000000
# 75%    180.000000   149.000000
# max    799.000000   560.000000

# %%
result.corr()
# Out:
#              MRP_Price  Offer_Price
# MRP_Price     1.000000     0.966893
# Offer_Price   0.966893     1.000000

# %%
result.MRP_Price.value_counts()
# Out:
# 25.00     12
# 30.00     11
# 10.00     11
# 120.00    10
# 100.00     9
#           ..
# 238.00     1
# 210.00     1
# 38.00      1
# 240.00     1
# 423.75     1
# Name: MRP_Price, Length: 133, dtype: int64

# %% [markdown]
# dropping the duplicate rows

# %%
result.shape
duplicate_rows_df=result[result.duplicated()]
print("Number of duplicste rows: ", duplicate_rows_df.shape)
result.count()
result.drop_duplicates()
result.head()
result.tail()
result.count()
# Out:
# Number of duplicste rows:  (1, 7)
# Product_Name        321
# Product_Quantity    321
# MRP_Price           321
# Offer_Price         321
# Vendor              321
# Category            321
# Qty_Unit            315
# dtype: int64

# %% [markdown]
# Qty_Unit column has many null values which required to be corrected.

# %%
sns.jointplot(x='Offer_Price',y='MRP_Price',kind='reg',data=result)

# %%
# checking the frequency distribution
result.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000277D739CD08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000277D9B075C8>]],
#       dtype=object)

# %%
# for each pair of features in the dataset, we can visualize scatter plot
sns.pairplot(result)

# %% [markdown]
# Detecting outliears

# %%
# finding outliears using box plot
sns.boxplot(x=result['Offer_Price'])

# %%
# finding outliears using box plot
sns.boxplot(x=result['MRP_Price'])

# %%
sns.pairplot(result)

# %%
plt.figure(figsize=(10,5))
c=result.corr()
sns.heatmap(c,annot=True)

# %%
#Check if there are any null values in the final dataset
result.isnull().sum()
# Out:
# Product_Name        0
# Product_Quantity    0
# MRP_Price           0
# Offer_Price         0
# Vendor              0
# Category            0
# Qty_Unit            6
# dtype: int64

# %%
#Which shops are part of the dataset
result.Vendor.unique()
# Out:
# array(['BigBasket', 'JioMart', 'Amazon'], dtype=object)

# %%
#Unique product categories
result.Product_Name.unique()
# Out:
# array(['Cabbage', 'Ridge Gourd/Beerakaya', 'Coriander Leaves/Kothimeera',
#        'Mosambi - Economy', 'Muskmelon - Netted Small/Kharbuja',
#        'Apple - Red Delicious/WashingtonRegular', 'Beetroot',
#        'Cucumber - English/Kheera', 'Kiwi - Green', 'Methi/Menthi kura',
#        'Papaya - Semi Ripe/Boppayi Pandu', 'Apple - Royal GalaRegular',
#        'Grapes - Bangalore Blue with Seed/Draksha', 'Coccinia/Dondakaya',
#        'Brinjal - Nagpur/Varikatri/Vankaya', 'Raw Mango',
#        'Palak 100 g+Ladies Finger+Cucumber+Capsicum Green (500g Each)+Bottle Gourd 1Kg',
#        'Palak 250g +Ladies Finger+Cucumber+Capsicum Green (500g Each) +Bottle Gourd 1kg',
#        'Sweet Potato/Chilakada Dumpa',
#        'Dates - Kimiawith Seed/Khajoora Pandu', 'Drumstick/Mulakada',
#        'Orange - ImportedRegular/Narinja/Santra',
#        'Orange - Imported/Narinja/Santra', 'Beans - Broad/Chikkudukaya',
#        'Brinjal - PurpleLong/Sannvankaya', 'Curry Leaves/Karivepaku',
#        'Mosambi/Battaiah Pandu', 'Tomato - Hybrid/Bengaluru Tamata',
#        'Bitter Gourd/Kakarkaya', 'Avocado/Venna Pandu',
#        'Broccoli - Florets',
#        'Capsicum - Red/Bengalur Mirapakayi/ Shimla Mirchi',
#        'Capsicum - Yellow/Bengalur Mirapakayi/ Shimla Mirchi',
#        'Colocasia/Chemagadda/Chamadumpa',
#        'Beans - Cluster/Goru Chikkudukaya',
#        'Cucumber - Mangalore/Dosakaya', 'Pear - GreenImported',
#        'Radish - White/Mullangi/ Mooli', 'Totapuri Mango',
#        'Lettuce - Iceberg', 'Beans - Cowpea/Bobbarlu/Lobhia',
#        'Coconut - Medium/Kobbari Kaaya', 'Himayath Mango',
#        'Brinjal - Bottle Shape/Vankaya', 'Mint Leaves/Pudina Aaku',
#        'Broccoli', 'Pumpkin Green - Cut', 'Banana - Yelakki/Aarati pandu',
#        'Onion - Organically Grown/Vulligadda/ Ullipaya/Pyaaz',
#        'Baby Potato/Chinna Alugadda', 'Snake Gourd/Potlakaya',
#        'Apple - FujiRegular', 'Apple - GreenPremium', 'Apricot - Dried',
#        'Kesar Mango',
#        'Potato - Organically Grown/Alugadda/Bangala Dumpa/aloo',
#        'Onion - Sambhar/Sambar Vulligadda', 'Coriander Leaves - Chopped',
#        'Amaranthus - Thotakura/Thotakura',
#        'Gongura Leaves/Puntikura/Gongura', 'Pomegranate - Peeled',
#        'bb Royal Idli Rice 5kg + Gota Urad 1kg + Raw Peanut 500g',
#        'Soya Chunks', 'Soya - Chunks',
#        'Organic - Brown Chana/Channa Brown',
#        'Organic - Brown Chana / Sengalu',
#        'Organic - Brown Channa / Sengalu', 'Channa - Brown',
#        'Rajma - White/Chitra', 'Channa Dal', 'Urad Whole/Gota Unpolished',
#        'Channa - Kabuli',
#        'BB Popular Channa Dal 1 kg + Urad Dal - Split 1 kg+BB Royal Rice - Dosa 2 kg',
#        'Moong - GreenSplit/Chilka', 'Green Moong Split/Chilka',
#        'Urad Dal Whole White', 'Lobia - White',
#        'Organic - Chana Dal / Sanaga Pappu',
#        'Organic - Chana Dal/Channa Unpolished', 'Mini Soya Chunks',
#        'Masoor Dal', 'Organic - Bengal Gram Dal / Sanagulu',
#        'Organic Fried Gram/Bengal Gram Dal',
#        'Organic - Roasted Bengal Gram Dal / Sanga Pappu',
#        'Organic - Urad Dal White (Split) / Minapappu',
#        'Organic - Urad Dal White (Split)Unpolished', 'Organic - Quinoa',
#        'Organic - Foxtail Millet / Italian (Thinai Rice)',
#        'Moong - GreenWhole/Sabut', 'Organic - Ragi Whole/Finger Millet',
#        'Organic - Ragi Whole / Ragulu', 'Unpolish - Urad Dal/Split',
#        'Organic - Urad Dal Black (Split)',
#        'Organic - Urad Dal Black (Split) / Minapappu', 'Jowar',
#        'Organic - Green Moong Whole / Pesara Pappu',
#        'Organic - Green Moong Whole', 'Organic Kabuli Chana/Channa',
#        'Organic - Kabuli Chana / Tella Muku Sengalu',
#        'Organic Little Millet - Samai Rice',
#        'Organic Little Millet/Samai Rice', 'Moong Dal', 'Popcorn - Seeds',
#        'Popcorn Seeds', 'Peas/Matar - White', 'White Peas/Matar',
#        'Rajma - Kashmiri', 'Organic - Red Masoor DalUnpolished',
#        'Organic - Red Masoor Dal / Erupu Kandulu',
#        'Organic Kodo Millet - Varagu Rice',
#        'Organic Kodo Millet/Varagu Rice', 'Soya - Mini Chunk',
#        'Peanuts/Mungaphali/Shengdana - Raw', 'Organic - Urad BlackWhole',
#        'Organic - Urad BlackWhole / Minapappu',
#        'Organic Barnyard Millet/Kudiraivali Rice',
#        'Tur Dal - Pesticide Free', 'Tur Dal',
#        'Organic - Rajma Chitra / Rajma', 'Organic Rajma Chitra',
#        'Mix Dal', 'Organic - Green Moong Dal (Split)', 'Moong Whole',
#        'Rajma - Red', 'Kabuli Chana - Pesticide Free',
#        'Urad - BlackSplit/Chilka', 'Organic - Masoor Black Whole',
#        'Organic - Black MasoordalWhole / Kandula', 'Green Peas/Matar',
#        'Peas/Matar - Green', 'Moth - Whole/Matki', 'Red Lobia',
#        'Lobia - Red', 'Masoor - BlackWhole/Sabut',
#        'Masoor Black Whole/Sabut', 'Moong Dal Unpolished',
#        'Organic - Mixed Dal', 'Organic - Bajra Wild / Kamlu',
#        'Organic - Bajra Wild / Pearl Millet',
#        'Organic - Bajra Wild/ Pearl Millet', 'Moth Whole/Matki',
#        'Matki/Moth - Whole', 'Organic Rajma Sharmili',
#        'Organic - Rajma Sharmili / Rajma', 'Soya Chunks - Mini',
#        'Toor/Arhar Dal - Desi', 'Urad - BlackWhole/Sabut',
#        'Moms Magic Cookies - Cashew & Almond Biscuits',
#        'Biscuits - Chand', 'Good Day Butter Cookies',
#        'Kitkat Mini 2 Finger Chocolate Covered Wafer',
#        'Kitkat 2 Finger Chocolate Covered Wafer Bar',
#        'Good Day Chocochip Cookies', 'Hide & Seek Caffe Mocha Cookies',
#        'Digestive Biscuits', 'Treat - Orange Biscuits',
#        'Treat Orange Cream Biscuits', 'Chocobakes Choc Filled Cookies',
#        'Dipped Cookie', 'ChocolatePro Health Vitamins',
#        'Kitkat 4 Finger Chocolate Covered Wafer Bar',
#        'Wafers - Waffy (Vanilla Flavor)', 'Biscuits - Salt', 'Krack Jack',
#        'Creame Biscuit - Strawberry', 'Choco - Pie',
#        'Cookies - Fruit & Nut', 'Milano Choco Chip Cookies',
#        'Cookies - Hide N Seek Milano', 'Biscuits - Kaju Badam',
#        'Biscuits - 50-50', '50-50 Sweet & Salty Biscuits',
#        'Munch Nuts Chocolate Coated Crunchy Wafer - Home Pack',
#        'Dark Fantasy - Luxuria Choco Fills',
#        'Dark Fantasy - Luxuria Choco Fills Biscuits - Cookies',
#        'Happy Happy Choco-Chip Cookies', 'Cookies - Chocolate Chip',
#        'Banana Oats Biscuits', 'Biscuits - Chai',
#        'Biscuits - Assorted Celebration', 'Krackjack Biscuits',
#        'Biscuit - ChocolateBournvitaPro Health Vitamins250 gPack of 9',
#        'Krackjack Original - Sweet & Salty Crackers Biscuits',
#        'Farmlite Digestive High Fibre Biscuits',
#        'Milano Centre Filled Dark Cookies - Choco Delight',
#        'Milano Center Filled Choco', 'Nice - Sugar Sprinkled Biscuits',
#        'Choco Pie', 'Biscuits - Salted', 'Monaco Cheesling',
#        'Monaco Cheeslings - Classic', '50-50 - Biscuits',
#        'Glucose Biscuits', 'Treat Burst - Choco Fills Cookies',
#        'Treat Burst Choco Fills Cookies',
#        'Cookies - Oatmeal (Sugar Free)',
#        'Sugar Free Cream Cracker Biscuits', 'Coconut Cookies',
#        'Cookies - Honey Oatmeal', 'Biscuits - Marie',
#        'Sugar Free Cream Cracker Biscuit - Masala', 'Biscuits - Googly',
#        'Dark Fantasy Yumfills Pie', 'Jeera Cookies',
#        'Just Ginger - The Ginger Biscuit With Real Tang',
#        'Waffy Choco Roll', 'Biscuits - Nice Coconutz', 'Cookies - Butter',
#        'Roll - Waffy (Strawberry)',
#        'Farmlite Biscuit - Oats And Chocolate',
#        'Farmlite Biscuit - Cookies - Oats And Chocolate',
#        'Marie Biscuits', 'Bathing Soap - Soft & Fresh',
#        'Hand Wash Liquid Refill - Skincare',
#        'Anti-Bacterial Hand Sanitiser', 'Anti-Bacterial Hand Sanitizer',
#        'Masterblaster Germ Protection Liquid Handwash Refill',
#        'Bathing Soap - Ayurvedic Classic 18 Herbs', 'Hand Sanitizer',
#        'Soap Bar - Soft Touch Silk Essence & Rose Water',
#        'Pro Sanitize Hand Sanitizer',
#        'Hand Sanitiser Gel With 72% Alcohol',
#        'Hand Sanitizer Gel with 72% Alcohol', 'Cream Beauty Bathing Bar',
#        'Mr. Magic Powder-To-Liquid Germ Protection Handwash Refill - Makes 200 ml Of Liquid',
#        'Antibacterial Hand Sanitizer - 72% Alcohol Based SanitizerNon-StickyGentle On Hands',
#        'Neem & Turmeric Soap', 'Bathing Soap - Neem & Turmeric',
#        'Soap - Neem & Turmeric', 'Hand Wash Liquid Refill - Original',
#        'Liquid Hand Wash - Original', 'Soap Bar',
#        'Soap Bar - Neem Tulsi and Aloevera',
#        'Soap Bar - Neem Tulsi & Aloevera',
#        'Total 10 Activ Naturol - Germ Protection Handwash Refill',
#        'Handwash - Total 10 ActivNatural Germ Protection',
#        'Handwash - Total 10',
#        'Bathing Soap - Ayurvedic Natural Glycerine',
#        'Bathing Soap - Glycerine Moisturising Soap',
#        'Sandal & Turmeric Soap', 'Cucumber & Coconut Soap',
#        'Bathing Soap - Cucumber & Coconut', 'Pure & Gentle Shower Gel',
#        'Dreamflower Fragrant Talc', 'Oil Clear & Glow Soap Bar',
#        'Sanitize Hand Sanitizer - 60% Alcohol Based SanitizerRegular',
#        'Coconut & Olive Oil Soap', 'Soap - Coconut & Olive Oil',
#        'Skincare Hand Wash Liquid Pump', 'Pure & Gentle Bathing Soap',
#        'Masterchefs Germ Protection Liquid Handwash Refill',
#        'Sandal & Turmeric Soap - Super Saver Pack', 'Total 10 Soap Bar',
#        'Total 10 Activ Naturol Germ Protection Hand Wash Refill',
#        'Masterchefs Germ Protection Liquid Hand Wash Refill',
#        'Soap Bar - Lemon & Tea Tree Oil 125 gm + Lemon & Tea Tree Oil Body Wash 250 ml',
#        'Bathing Soap - Sandal & Almond Milk', 'Soft & Fresh Soap Bar',
#        'Purifying Turmeric Soap',
#        'Purifying Turmeric Natural Ayurvedic Soap',
#        'Total 10 - Germ Protection Handwash',
#        'Body Wash - Scarlet Blossom',
#        'Bodywash - Aroma Therapy Absolute RelaxImported Shower Gel',
#        'Shower Gel - Aroma Absolute Relax', 'Cool Soap',
#        'Almond & Rose Soap', 'Bathing Soap - Almond & Rose',
#        'Original Soap', 'Shower Gel - Frangipani & Oil Body WashWomen',
#        'Bathing Soap - Original Neem', 'Bathing Soap - Ayurvedic',
#        'Soap Bar-Lemon & Tea Tree Oil+Cooling Mint Soap+Berry Blast Soap (75 g each x 2)',
#        'Multani Mitti - Body Cleanser', 'Hand Wash - Mild',
#        'Shower Gel - Pure Impact Body WashMen',
#        'Shower Gel - Active Clean Body WashMen',
#        'Gel Bathing Bar - Multi Variant (Buy 4 & Get 1 Free125 g each)',
#        'Gel Bathing Bar - Multi Variant',
#        'Cool Bath Soap - 99.9% Germ Protection',
#        'Yuzu Citrus Body Wash & Shower Gel - Refresh',
#        'Hand Wash - Nature Germ Protection', 'Ponds Starlight Talc',
#        'Deeply Nourishing Body Wash', 'Shower Gel - AromaAbsolute Relax',
#        'Ayurveda Handmade Soap',
#        'Ayurveda Handmade Soap Pack of 3 - Get 75 gm Free',
#        'Good Life Rajma ', 'Good Life Dal Mi', 'Good Life Urad W',
#        'Good Life Tur Da', 'Tip Top Roasted ', '24 Mantra Organi',
#        'Good Life Urad D', 'Good Life Roaste', 'Good Life Masoor',
#        'Good Life Kabuli', 'Tata Sampann Hig', 'Tip Top Moong Da',
#        'Tip Top Moong Ch', "D'nature Fresh Natural Blue Berries",
#        'Fresh Banana Robusta', 'Fresh Water Melon - Kiran',
#        'Fresh Mango Raw', 'Fresh Mosambi', 'Fresh Pineapple',
#        'Fresh Mango Banganpally', 'Fresh Mango',
#        'Del Monte Premium Pitted California  Prunes Health Snack',
#        'Del Monte Dried Cranberries',
#        'Being Marwari Gota Dry Coconuts (Medium',
#        'Fresh Produce Mango - Malgoa', 'Fresh Pomegranate'], dtype=object)

# %%
result['discount'] = (result.MRP_Price - result.Offer_Price) *100 / result.MRP_Price

# %%
result
# Out:
#                                Product_Name Product_Quantity  MRP_Price  \
# 0                                   Cabbage                1      23.75
# 1                     Ridge Gourd/Beerakaya              500      37.50
# 3               Coriander Leaves/Kothimeera              100      37.50
# 6                         Mosambi - Economy                3     123.75
# 7         Muskmelon - Netted Small/Kharbuja                1      53.75
# ..                                      ...              ...        ...
# 31      D'nature Fresh Natural Blue Berries                1     799.00
# 36      D'nature Fresh Natural Blue Berries              500     799.00
# 37  Being Marwari Gota Dry Coconuts (Medium              500     300.00
# 38             Fresh Produce Mango - Malgoa              500     690.00
# 39                        Fresh Pomegranate                1     650.00
#
#     Offer_Price     Vendor             Category Qty_Unit   discount
# 0          19.0  BigBasket  FruitsAndVegitables       pc  20.000000
# 1          30.0  BigBasket  FruitsAndVegitables        g  20.000000
# 3          30.0  BigBasket  FruitsAndVegitables        g  20.000000
# 6          99.0  BigBasket  FruitsAndVegitables       kg  20.000000
# 7          43.0  BigBasket  FruitsAndVegitables       pc  20.000000
# ..          ...        ...                  ...      ...        ...
# 31        530.0     Amazon               Fruits       kg  33.667084
# 36        530.0     Amazon               Fruits        g  33.667084
# 37        169.0     Amazon               Fruits        g  43.666667
# 38        540.0     Amazon               Fruits        g  21.739130
# 39        560.0     Amazon               Fruits       kg  13.846154
#
# [321 rows x 8 columns]

# %%
sns.pairplot(result)
