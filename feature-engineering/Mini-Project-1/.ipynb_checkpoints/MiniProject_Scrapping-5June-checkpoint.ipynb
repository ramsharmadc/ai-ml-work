# %% [markdown]
# # INTRODUCTION:
#
#
#  - The goal of this miniproject is to recommend the best online store in terms of price for users after comparing the price across the stores for various FMCG products.
#  - The data about the products is obtained via Web scrapping.
#
# >Group Name: __DATA SCIENTISTS__ <br>
# >Group Members: __Soujanya M, Ramya B, Suresh R__

# %% [markdown]
# # OVERALL APPROACH:
#
# The four tasks that will be done as a part of this exercise will be as follows:
#
#     A. Data Acquisition
#     B. Data Cleaning
#     C. Data Integration
#     D. Exploratory Data Analysis and Recommendation

# %% [markdown]
# # Data Acquisition
#
# ## Approach:
#
#  1.  Identify set of categories and products that we want to scrap from various online e-commerce platforms.
#      >There are around 30 categories and 150 items identified for web scrapping
#  2.  Choose e-commerce platforms
#      >Following platforms have been chosen for scrapping
#      - Big Basket
#      - DMart
#      - Grofers
#  3.  Search the products on the browser and observe the URL/AJAX calls made as a part of fetching data from server
#  4.  Identify various CSS classes for product attributes like Product name, MRP, Special Price
#  5.  Write code to perform web scrapping for each of the platforms and store the results in a separate CSV file for later use
#      > The results are stored in respective csv files as follows
#      - big_basket.csv
#      - dmart.csv
#      - grofers.csv

# %% [markdown]
# ## FMCG Categories and Products

# %%
#Necessary Library Imports
from bs4 import BeautifulSoup
import requests 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#The input file items.csv contains various product categories and brands for which scrapping has to be performed
df_products = pd.read_csv("items.csv" )
print("Total categories to be scrapped ", len(df_products["Product"].unique()))  
print("Total products to be scrapped ", df_products.shape[0])
# Out:
# Total categories to be scrapped  30
# Total products to be scrapped  142

# %% [markdown]
# ## Scrapping Bigbasket
#
#  - The URL for big basket data is different for first page and subsequent pages.
#  - So, we need to maintain two separate URLs in the code
#  - Since, we are very specific about each product, scrapping 2 pages is more than enough

# %%
#Big Basket Scrapping
def search_bigbasket(search_brand, search_product):
    
    #Max pages to scrap
    max_pages = 2
    
    #Product full name
    searchStr = search_brand + " " + search_product
    
    #URL for page 1
    url_page_1 = "https://www.bigbasket.com/custompage/getsearchdata/?type=deck&slug={0}"
    
    #URL for subsequent pages
    url_for_page_n = "https://www.bigbasket.com/product/get-products/?slug={0}&page={1}&tab_type=[%22all%22]&sorted_on=relevance&listtype=ps"
    
    #Replace spaces in the product name with +
    search_str_encoded = searchStr.replace(" ","+")
    
    #Form actual URL for page 1
    url = url_page_1.format(search_str_encoded)
 
    #Necessary request headers
    headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'}
    
    #Get the response for page 1
    productsInfo = requests.get(url, headers=headers).json()
    
    #Extract product data into a dictionary object
    products =  productsInfo['json_data']['tab_info'][0]['product_info']['products']
    product_data=[]
    for product in  products:
        options = product['all_prods']
        if(not options): 
            product_data.append({"search_brand": search_brand, "search_product": search_product, "shop": "Big Basket", "product_name": str(product['p_brand']).strip() + " " + str(product['p_desc']).strip(), "weight":product['w'], "mrp": product['mrp'], "special_price": product['sp'] })
            continue
        for option  in product['all_prods']:
            product_data.append({"search_brand": search_brand, "search_product": search_product, "shop": "Big Basket",  "product_name": str(product['p_brand']).strip() + " " + str(product['p_desc']).strip(), "weight":option['w'],
                                 "mrp": option['mrp'], "special_price": option['sp'] }) 
 
    
    #Do it for subsequent pages     
    for page in range(2,max_pages):
        newurl = url_for_page_n.format(search_str_encoded, page) 
        productsInfo = requests.get(newurl, headers=headers).json()
        products =  productsInfo['tab_info']['product_map']['all']['prods']

        for product in  products:
            options = product['all_prods']
            if(not options): 
                product_data.append({"search_brand": search_brand, "search_product": search_product, "shop": "Big Basket",    "product_name": str(product['p_brand']).strip() + " " + str(product['p_desc']).strip(), "weight":product['w'], "mrp": product['mrp'], "special_price": product['sp'] })
                continue
            for option  in product['all_prods']:
                product_data.append({"search_brand": search_brand, "search_product": search_product,  "shop": "Big Basket",  "product_name": str(product['p_brand']).strip() + " " + str(product['p_desc']).strip(), "weight":option['w'], "mrp": option['mrp'], "special_price": option['sp'] })

    #Return the scrapped data           
    return product_data

# %% [markdown]
# ## Scrapping DMart
#
#  - The URL for DMart is same for all pages as long as we include the page number.
#  - So, we need to maintain a URL with placeholder for page in the code
#  - DMart requires a Store Id be sent in the header to be sent. Otherwise, it will return wrong results
#  - Since, we are very specific about each product, scrapping 2 pages is more than enough

# %%
#Dmart Scrapping
def search_dmart(search_brand, search_product):
    #Max pages to scrap
    max_pages = 2
    #Product full name
    searchStr = search_brand + " " + search_product
    #URL for page 
    url_page  = "https://digital.dmart.in/api/v1/search/{0}?page={1}"
    #Necessary request headers
    headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'}
    
    #DMart requires store Id 
    headers['storeId']='10657'
    #Replace spaces in the product name with +
    search_str_encoded = searchStr.replace(" ","+")
    
    #Extract product data into a dictionary object
    product_data=[]
    for page in range(1,max_pages):
        url = url_page.format(search_str_encoded, page)
        productsInfo = requests.get(url, headers=headers).json()
        #If the scrapping did not yield any products, just continue with next product
        products=productsInfo.get( 'suggestionView')
        if(not products):
            continue
     
        for product in  products:
            skus = product['skus']
            for sku in skus:  
                if(sku['defining']):
                    name =   sku.get( 'name',  product['name']).strip()
                    product_data.append({"search_brand": search_brand, "search_product": search_product, "shop": "DMart",   "product_name": name,"weight": sku['defining'][0]['volume'], "mrp": sku['price_MRP'], "special_price": sku['price_SALE'] })
    #Return the scrapped data           
    return product_data
# Out:
#    search_brand search_product   shop  \
# 0     3%20roses            Tea  DMart
# 1     3%20roses            Tea  DMart
# 2     3%20roses            Tea  DMart
# 3     3%20roses            Tea  DMart
# 4     3%20roses            Tea  DMart
# 5     3%20roses            Tea  DMart
# 6     3%20roses            Tea  DMart
# 7     3%20roses            Tea  DMart
# 8     3%20roses            Tea  DMart
# 9     3%20roses            Tea  DMart
# 10    3%20roses            Tea  DMart
# 11    3%20roses            Tea  DMart
# 12    3%20roses            Tea  DMart
# 13    3%20roses            Tea  DMart
# 14    3%20roses            Tea  DMart
# 15    3%20roses            Tea  DMart
# 16    3%20roses            Tea  DMart
# 17    3%20roses            Tea  DMart
# 18    3%20roses            Tea  DMart
# 19    3%20roses            Tea  DMart
# 20    3%20roses            Tea  DMart
# 21    3%20roses            Tea  DMart
# 22    3%20roses            Tea  DMart
# 23    3%20roses            Tea  DMart
# 24    3%20roses            Tea  DMart
# 25    3%20roses            Tea  DMart
#
#                                          product_name       weight     mrp  \
# 0                   Brooke Bond 3 Roses Tea : 500 gms       500 gm  300.00
# 1                   Brooke Bond 3 Roses Tea : 250 gms       250 gm  155.00
# 2        Brooke Bond 3Roses Nature Care Tea : 500 gms       500 gm  320.00
# 3                 Dabur Hajmola Regular : 120 Tablets  120 Tablets   40.00
# 4               Eno Fruit Salt Lemon Flavour : 30 gms        30 gm   48.00
# 5                       Tata Tea Agni Dust Tea : 1 kg         1 kg  240.00
# 6   Wagh Bakri Strong & Refreshing Leaf Tea : 500 gms       500 gm  210.00
# 7          Tata Tea Chakra Gold Premium Tea : 500 gms       500 gm  300.00
# 8          Tata Tea Chakra Gold Premium Tea : 250 gms       250 gm  150.00
# 9                  Brookebond Red Label Tea : 100 gms       100 gm   35.00
# 10                        Tata Gemini Dust Tea : 1 kg         1 kg  308.00
# 11                     Tata Gemini Dust Tea : 500 gms       500 gm  188.00
# 12                     Tata Gemini Dust Tea : 250 gms       250 gm   98.00
# 13                            Tata Tea Agni : 250 gms       250 gm   85.00
# 14                               Tata Tea Agni : 1 kg         1 kg  330.00
# 15                            Tata Tea Gold : 250 gms       250 gm  130.00
# 16                            Tata Tea Gold : 500 gms       500 gm  259.00
# 17                               Tata Tea Gold : 1 kg         1 kg  457.00
# 18                         Tata Tea Premium : 500 gms       500 gm  215.00
# 19                            Tata Tea Premium : 1 kg         1 kg  400.00
# 20                   Brooke Bond Red Label Tea : 1 kg         1 kg  450.00
# 21                Brooke Bond Red Label Tea : 500 gms       500 gm  220.00
# 22                Brooke Bond Red Label Tea : 250 gms       250 gm  115.00
# 23           Wagh Bakri Premium Leaf Tea Pouch : 1 kg         1 kg  400.00
# 24             Brooke Bond Taj Mahal Tea : 1 kg (New)         1 kg  600.00
# 25      Tetley Green Tea Lemon & Honey : 100 Tea-Bags     100 Bags  470.00
#
#    special_price
# 0         275.00
# 1         145.00
# 2         290.00
# 3          37.00
# 4          44.00
# 5         220.00
# 6         192.00
# 7         275.00
# 8         139.00
# 9          32.00
# 10        280.00
# 11        169.00
# 12         88.00
# 13         78.00
# 14        290.00
# 15        122.00
# 16        219.00
# 17        417.00
# 18        190.00
# 19        365.00
# 20        410.00
# 21        200.00
# 22        105.00
# 23        365.00
# 24        554.00
# 25        425.00

# %% [markdown]
# ## Scrapping Grofers
#
#  - The URL for Grofers is same for all pages as long as we include the page number.
#  - Grofers requires a special header to be sent. Otherwise, it won't return any results
#  - So, we need to maintain a URL with placeholder for page in the code
#  - Since, we are very specific about each product, scrapping 2 pages is more than enough

# %%
#Grofers Scrapping
def search_grofers(search_brand, search_product):
    #Max pages to scrap
    max_pages = 2
    #Product full name
    searchStr = search_brand + " " + search_product
    #URL for page. This should include Longitude and Latitude as well. 
    url_page  = "https://grofers.com/v5/search/merchants/26659/products/?lat=17.4196281427546&lon=78.3790778036223&q={0}&suggestion_type=0&t=1&start={1}&size=48"
    #Necessary request headers
    headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'}
    #Grofers requires this header 
    headers['app_client'] = 'consumer_web' 
    #Replace spaces in the product name with +
    search_str_encoded = searchStr.replace(" ","+")
    #Extract product data into a dictionary object
    product_data=[]
    for page in range(1,max_pages):
        start_pos = (page-1)*48
        if(start_pos==0):
            start_pos = 1
        #Create page specific URL
        url = url_page.format(search_str_encoded, start_pos)
        productsInfo = requests.get(url, headers=headers).json()
        #If the scrapping did not yield any products, just continue with next product
        products= productsInfo.get('products')
        if(not products):
            break
        for product in  products:
            prod_variants = product['variant_info']
            for var in prod_variants:
                product_data.append({"search_brand": search_brand, "search_product": search_product,   "shop": "Grofers",  "product_name": var["line_1"],"weight": var["unit"], "mrp": var["mrp"], "special_price": var["price"]})
    #Return the scrapped data    
    return product_data
# Out:
#   search_brand search_product     shop                      product_name  \
# 0    3%20Roses            Tea  Grofers      Brooke Bond 3 Roses Dust Tea
# 1    3%20Roses            Tea  Grofers      Brooke Bond 3 Roses Dust Tea
# 2    3%20Roses            Tea  Grofers       Grofers Happy Day Kadak Tea
# 3    3%20Roses            Tea  Grofers  Grofers Happy Day Prime Gold Tea
# 4    3%20Roses            Tea  Grofers  Grofers Happy Day Prime Gold Tea
#
#   weight  mrp special_price
# 0  500 g  300           300
# 1  250 g  155           155
# 2   1 kg  200           179
# 3  250 g  115            88
# 4   1 kg  440           364

# %% [markdown]
# ## Perform Scrapping for all online portals
#
#  - The following section performs scrapping for all the 3 portals for the products mentioned in input file.
#  - Ensure input.csv file is present in the current directory before calling this method.

# %%
# Scrapping for all sites
def perform_scrapping():
    #Read all items for which scrapping is needed
    df_input   = pd.read_csv("items.csv" )
    #Define an empty dataframe to store results for each of the shops
    column_names =   ["search_brand","search_product", "shop",   "product_name", "weight", "mrp", "special_price"]
    
    df_bigbasket = pd.DataFrame(columns = column_names)
    df_dmart = pd.DataFrame(columns = column_names)
    df_grofers = pd.DataFrame(columns = column_names)
    
    #For each of the products, peform scrapping
    for ( idx , search_brand, search_product) in df_input.itertuples():
  
        print('Scrapping BigBasket for ', idx, search_brand, search_product)
        product_data = search_bigbasket(search_brand, search_product)
        df_bigbasket = df_bigbasket.append(product_data[:5])

        print('Scrapping Grofers for ', idx, search_brand, search_product)
        product_data = search_grofers(search_brand, search_product)
        df_grofers = df_grofers.append(product_data[:5])

        print('Scrapping BigBasket for ', idx, search_brand, search_product)
        product_data = search_dmart(search_brand, search_product)
        df_dmart = df_dmart.append(product_data[:5])
  
    #Store final results for each of the stores in separate csv file
    df_bigbasket.to_csv('big_basket.csv', index=False,encoding='utf-8')
    df_grofers.to_csv('grofers.csv', index=False, encoding='utf-8')
    df_dmart.to_csv('dmart.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Scrapping Results
# This section shows the results of the scrapping

# %%
#Call scrapping routine
perform_scrapping()
#Load scrapped data into data frames and look at the metrics
df_bb  = pd.read_csv("big_basket.csv")
df_dmart  = pd.read_csv("dmart.csv")
df_grofers  = pd.read_csv("grofers.csv")
 
print("Bigbasket returned products count:" , df_bb.shape[0] )
print("DMart returned products count:" , df_dmart.shape[0] )
print("Grofers returned products count:" , df_grofers.shape[0] )
# Out:
# Bigbasket returned products count: 655
# DMart returned products count: 687
# Grofers returned products count: 603

# %% [markdown]
# # Data Cleaning
#
# ## Approach:
#
#  For each of thep files generated in the previous section, perform following cleanup steps
#  1. Separate weight and measure to separate columns from weight column
#  2. Calculate the derived column discount based on MRP and Special Price
#  3. Drop duplicate products that may have arrived due to wrong search results given by the site
#  4. Re-arrange columns in proper order
#  5. Save final set of products in respective csv files as follows
#      - big_basket_cleaned.csv
#      - dmart_cleaned.csv
#      - grofers_cleaned.csv

# %% [markdown]
# ## Clean up for Big Basket

# %%
df  = pd.read_csv("big_basket.csv",  engine='python')
print(df.product_name.unique())
print(df.weight.unique())
# Out:
# ['3 Roses Tea Dust' '3 Roses Tea - Natural Care' '3 Roses Dust Tea'
#  '3 Roses Top Star' '7 Up Soft Drink - Lemon' '7 Up Soft Drink'
#  'ACT II Microwave Popcorn Original'
#  'ACT II Instant Popcorn - Chilly Surprise'
#  'ACT II Instant Popcorn - Butter Delite'
#  'Adidas Deo Body Spray - Team Force'
#  'Adidas Deo Body Spray - Pure Game For Men'
#  'Adidas Deo Body Spray - Dynamic Pulse'
#  'Adidas Deo Body Spray - Ice Dive' 'Anurag Pooja Oil - Gold Refined, RB'
#  'Sundrop Oil - Heart' 'Saffola Gold - Pro Healthy Lifestyle Edible Oil'
#  'Appy Fizz Apple Juice Based Drink' 'Aswini Hair Oil'
#  'Bisleri Mineral Water' 'Coca Cola Soft Drink' 'Pepsi Soft Drink'
#  'Britannia Bake Rusk Toast' 'Red Label Tea'
#  'Red Label Tea - Natural Care' 'Bru Filter Coffee - Green Label'
#  'Bru Instant Coffee' 'Cadbury Dairy Milk Chocolate'
#  'Cadbury Dairy Milk Chocolate Home Treats Pack'
#  'Cadbury Dairy Milk Fruit & Nut Chocolate Bar'
#  'Cadbury 5 Star Chocolate Bar' 'Cadbury 5 Star Chocolate Home Pack'
#  'Cadbury 5 Star 3D Home Treats Pack'
#  'Cadbury Bournvita -Â\xa05 Star Magic, Chocolate Health Drink'
#  'bb Popular Channa Dal' 'bb Royal Channa Dal'
#  'Cinthol Confidence+ Bath Soap - 99.9% Germ Protection'
#  'Cinthol Cool Bath Soap - 99.9% Germ Protection'
#  'Cinthol Original Bath Soap - 99.9% Germ Protection' 'Cinthol Cool Talc'
#  'Cinthol Original Talc' 'Clinic Plus Strong & Long Health Shampoo'
#  'Clinic Plus Shampoo - Strong & Extra Thick'
#  'Close Up Everfresh+ Anti-Germ Gel Toothpaste - Red Hot'
#  'Close Up Deep Action Eucalyptus Mint Anti Germ Gel Toothpaste'
#  'Coca Cola Soft Drink - Original Taste'
#  'STAYFREE Sanitary Pads - Secure Xl Cottony Soft, with Wings'
#  'STAYFREE Secure - Cottony X-Large Sanitary Napkins'
#  'Sundrop Nutrilite Oil - Blend' 'Sundrop Heart Oil - Vegetable'
#  'Sunsilk Conditioner - Thick & Long'
#  'Sunsilk Conditioner - Perfect Straight Nourishing'
#  'Sunsilk Coconut and Aloe Vera Volume Hair Conditioner'
#  'Sunsilk Coconut & Aloe Vera Volume Hair Conditioner'
#  'Sunsilk Conditioner - Lusciously Thick & Long Nourishing'
#  'Sunsilk Nourishing Soft & Smooth Shampoo'
#  'Sunsilk Stunning Black Shine Shampoo'
#  'Sunsilk Lusciously Thick & Long Shampoo' 'Taj Mahal Tea'
#  'bb Popular Tamarind/Imli - Seedless' 'bb Royal Deseeded Tamarind/Imli'
#  'Rajini Tamarind cake' 'Tang Instant Drink Mix - Orange'
#  'Tang Instant Drink Mix - Lemon' 'Tata Tea Gold Leaf Tea'
#  'Tata Tea Gold Leaf Tea 1 kg + Leaf Tea 250 g' 'Thums Up Soft Drink'
#  'bb Popular Toor/Arhar Dal' 'bb Royal Toor Dal/Arhar Dal - Desi'
#  'TRESemme Conditioner - Hair Fall Defense'
#  'TRESemme Keratin Smooth - Argan Oil Conditioner'
#  'TRESemme Conditioner - Smooth & Shine'
#  'TRESemme Keratin Smooth With Argan Oil Shampoo'
#  'TRESemme Shampoo - Smooth & Shine' 'TRESemme Hair Fall Defense Shampoo'
#  'Tropicana 100% Mixed Fruit Juice'
#  'Whisper Sanitary Pads - Extra Large Plus, Clean, Ultra'
#  'Whisper Sanitary Pads - Ultra Nights XL+ Wings'
#  'Whisper Sanitary Pads - Choice Ultra Wings Extra Large'
#  'bb Royal Stone Flower' 'bb Royal Organic - Bajra Wild / Kamlu'
#  'Yardley London English Lavender Perfumed Talc'
#  'Yardley London English Rose Perfumed Talc']
# ['250 g' '100 g' '500 g' '6X250 ml' '250 ml' '4x250 ml' '2.25 L'
#  '2x2.25 L' '99 g' '30 + 10 gm Free' '3x77 g' '6x77 g' '77 g' '150 ml'
#  '910 g' '455 g' '5 L' '1 L' '2x1 L' '600 ml' '50 ml' '180 ml' '2 L'
#  '12x300 ml' '300 ml' '6x300 ml' '72 g' '200 g' '50 g' '23 g' '126 g'
#  '80 g' '36 g' '40 g' '2x40 g' '180 g' '2x500 g' '1 kg' '2 kg' '8x100 g'
#  '4x100 g' '300 g' '340 ml' '80 ml' '650 ml' '175 ml' '150 g' '1.75 L'
#  'Combo' '2 pcs' '6 pcs' '3 pcs' '1 pc' '3x200 g' '200 + 200 gm' '3x300 g'
#  '125 g' '75 g' '750 ml' '200 ml' '500 ml' '3x(3x100 g)' '5x100 g' '800 g'
#  '240 ml' '18 ml' '220 ml' '2x2 L' '2x150 ml' '15 kg' '1.2 L' '2x1.2 L'
#  '2x100 g' '3x150 g' '3x100 g' '6x150 g' '2x500 ml' '72 ml' '4x75 g'
#  '4x125 g' '6x125 g' '450 g' '5 kg' '100 ml' '9 g' '7 g' '8 g' '2x125 g'
#  '8x125 g' '56 g' '185 ml' '1.5 L' '190 ml' '32.5 g' '2x25 pcs' '130 g'
#  '2x100 pcs' '140 g' '35 g' '6x75 g' '450 ml' '2x975 ml' '975 ml'
#  '3x975 ml' '2x65 ml' '65 ml' '360 ml' '125 ml' '2x600 ml' '6x250 ml'
#  '25 g' '400 g' '4x180 ml' '227 g' 'Combi' '1 nos' '3x340 ml' '6x200 ml'
#  '12x200 ml' '400 ml' '135 ml' '350 ml' '273 g' '4x500 ml' '120 ml' '20 g'
#  '3x(3x125 g)' '5x125 g' '3x1 L' '10 kg' '25 kg' '215 ml' '3x750 ml'
#  '2x750 ml' '29 g' '1.25 L' '7 pads' '20 Pads' '6 pads' '40 pcs' '3 L'
#  '190 g' '2x1.75 L' '2x1.25 L' '580 ml' '15 pcs' '44 pcs' '30 pcs'
#  '30 Pads' '20 pcs' '2x1 kg']

# %% [markdown]
# <font color=red>Inference: Clean up is required as follows.</font>
#
#  - There are products with combo packs. So, remove them as identifying individual product becomes tough during recommendation
#  - Remove products with weights that has invalid characters other than numbers
#  - Drop duplicate products that may have arrived due to wrong search results given by the site

# %%
#Cleanup routine for bigbasket
def clean_bigbasket_data():
    #Read the dataset
    df  = pd.read_csv("big_basket.csv",  engine='python')
    # Pattern to identify combo packs
    searchfor = ['x', 'X','\+','Comb',  'each', '\(']
    #Drop the rows with above patterns
    df.drop( df[ df["weight"].str.contains('|'.join(searchfor)) ].index,inplace=True  )
    #Separate weight in to weight, measure
    df[['weight','measure']] = df.weight.str.split(expand=True) 
    #Remove rows that have invalid weight entries
    df.drop( df[~df["weight"].str.replace('.','',1).str.isnumeric() ].index,inplace=True  )
    #Check if product name has the keyword we searched for
    df['good_product_ind'] = [x[1] in x[0] for x in zip(df['product_name'], df['search_brand'])]
    #Drop the products that don;t meet the above criteria
    df.drop( df[~df["good_product_ind"] ].index,inplace=True  )   
    #Creae weight_measure column by combining weight and measure
    df[ 'weight_measure' ] = df.weight.str.strip() + df.measure.str.strip()
    #Re-order columns
    df = df[['search_product','search_brand', 'shop' ,'product_name','weight', 'measure', 'weight_measure', 'mrp','special_price']]
    #Calculate discount
    df['discount'] = (df.mrp - df.special_price) *100 / df.mrp 
    #Remove duplicate entries for given product and weight
    df.drop_duplicates(subset=['product_name','weight'], keep='last', inplace=True)
    #Save the results to big_basket_cleaned
    df.to_csv('big_basket_cleaned.csv', index=False)

# %% [markdown]
# ## Clean up for DMart

# %%
df  = pd.read_csv("dmart.csv",  engine='python')
print(df.product_name.unique())
print(df.weight.unique())
# Out:
# ['Brooke Bond 3 Roses Tea : 500 gms' 'Brooke Bond 3 Roses Tea : 250 gms'
#  'Brooke Bond 3Roses Nature Care Tea : 500 gms'
#  'Dabur Hajmola Regular : 120 Tablets'
#  'Eno Fruit Salt Lemon Flavour : 30 gms' '7 Up : 2.25 Litres'
#  'Thums Up : 1.75 Litres' 'Rebalanz Tasty Apple Drink : 200 ml'
#  'India Gate Basmati Rice - Feast Rozzana : 5 kgs'
#  'Daawat Rozana Super Basmati Rice : 5 kgs'
#  'Daawat Devaaya Basmati Rice : 5 kgs' 'Daawat Super Basmati Rice : 1 kg'
#  'Kohinoor Charminar Select - Basmati Rice : 5 kgs'
#  'Saffola Tasty Oil : 1 Litre' 'Saffola Tasty Oil : 5 Litres'
#  'Saffola Active Oil : 1 Litre'
#  'Santoor Sandal & Turmeric Soap : 4x75 gms'
#  'Santoor Sandal & Turmeric Soap : 4x125 gms'
#  'Santoor Sandal & Turmeric Soap : 4x150 gms'
#  'Santoor Sandal Almond Soap : 3x150 gms'
#  'Santoor Handwash Pouch : 750 ml'
#  'Stayfree Secure Cotton Soft Regular : 20 U'
#  'Stayfree Secure Cottony Wings XL : 20 U'
#  'Stayfree Dry Max All Night XL : 42 U'
#  'Sofy Body fit Antibacterial XL Pads : 54 U'
#  'Whisper Choice Ultra XL Wings Pads : 6 U' 'Sundrop Heart Oil : 5 Litres'
#  'Sundrop Superlite Advanced Sunflower Oil : 1 Litre'
#  'Sundrop Superlite Advanced Sunflower Oil : 5 Litres'
#  'Sunsilk Lusciously Thick & Long Shampoo : 650 ml'
#  'Sunsilk Stunning Black Shine Shampoo : 650 ml'
#  'Premia Cassia Taj : 100 gms' 'Premia Emli : 200 gms'
#  'Ready Tamarind : 500 gms' 'Goldy Cake Tamarind : 1 kg'
#  'Goldy Cake Tamarind : 500 gms' 'Tata Tea Gold : 250 gms'
#  'Tata Tea Gold : 500 gms' 'Tata Tea Gold : 1 kg'
#  'DMart Healthy Choice Unpolished Toor Dal : 1 kg'
#  'Tur Dal Premium Gujarat : 500 gms' 'Tur Dal Premium Gujarat : 1 kg'
#  'Tur Dal Latur : 500 gms' 'Tur Dal Latur : 1 kg'
#  'TRESemme Keratin Smooth Shampoo : 580 ml'
#  'Vim Dishwash Gel - Lemon : 900 ml' 'Vim Dishwash Bar : 125 gms'
#  'Vim Dishwash Bar : 300 gms' 'Whisper Choice Wings'
#  'Whisper Choice Ultra XL Wings Pads : 20 U'
#  'Whisper Ultra Clean XL+ Wings Pads : 44 U']
# ['500 gm' '250 gm' '120 Tablets' '30 gm' '2.25 L' '1.75 L' '200 ml'
#  '200 gm' '260 ml' '150 ml' '600 gm' '50 ml' '900 ml' '1 L' '5 L' '500 ml'
#  '450 ml' '100 ml' '300 ml' '120 ml' '450 gm' '750 gm' '400 gm' '75 gm'
#  '100 gm' '1 kg' '50 gm' '120 gm' '137 gm' '162 gm' '170.5 gm' '632.5 gm'
#  '4x150 gm' '4x100 gm' '3x150 gm' '650 ml' '25 ml' '80 ml' '580 ml'
#  '2x150 gm' '130 gm' '300 gm' '40 gm' '6 U' '4 U' '1 U' '2 U' '2x200 gm'
#  '4x125 gm' '3x75 gm' '125 gm' '150 gm' '2 L' '750 ml' '175 ml' '6x100 gm'
#  '3x100 gm' '340 ml' '60 ml' '20 ml' '860 ml' '4X125 gm' '70 gm' '900 gm'
#  '75 U' '30 ml' '240 ml' '190 ml' '975 ml' '430 ml' '800 ml' '350 ml'
#  '180 ml' '3x125 gm' '25 gm' '250 ml' '220 ml' '391 gm' '175 gm' '10 kg'
#  '6x125 gm' '5 kg' '4x75 gm' '3X150 gm' '20 U' '42 U' '54 U' '44 U']

# %% [markdown]
# <font color=red>Inference: Clean up is required as follows.</font>
#
#  - There are products with combo packs. So, remove them as identifying individual product becomes tough during recommendation
#  - Remove products with weights that has invalid characters other than numbers
#  - Drop duplicate products that may have arrived due to wrong search results given by the site
#  - Product name contains weight. Remove it.

# %%
#Cleanup routine for dmart
def clean_dmart_data():
    #Read the dataset
    df  = pd.read_csv("dmart.csv")
    # Pattern to identify combo packs
    searchfor = ['x', 'X', 'W', 'Bags','Sachets','Drops','Wipes','U','Wipe','Pellets','Cubes','unit','units','tablets',"\+",'XL','L','M','S','Set','Pink']
    #Drop the rows with above patterns
    df.drop( df[ df["weight"].str.contains('|'.join(searchfor)) ].index,inplace=True  )
    #Drop the rows with zero weights
    df.drop( df[ df["weight"] == "0" ].index,inplace=True  )
    #Separate weight in to weight, measure
    df[['weight','measure']] = df.weight.str.split(expand=True) 
    #Replace gm meausre to g to make it consistent with other shops 
    df[ 'measure' ] = df.measure.str.replace('gm','g') 
    #Remove rows that have invalid weight entries
    df.drop( df[~df["weight"].str.replace('.','',1).str.isnumeric() ].index,inplace=True  )
    #Creae weight_measure column by combining weight and measure
    df[ 'weight_measure' ] = df.weight.str.strip() + df.measure.str.strip()
    #Check if product name has the keyword we searched for
    df['good_product_ind'] = [x[1] in x[0] for x in zip(df['product_name'], df['search_brand'])]
    #Drop the products that don;t meet the above criteria
    df.drop( df[~df["good_product_ind"] ].index,inplace=True  )   
    #Re-order columns
    df = df[['search_product','search_brand', 'shop' ,'product_name','weight', 'measure', 'weight_measure', 'mrp','special_price']]
    #Calculate discount
    df['discount'] = (df.mrp - df.special_price) *100 / df.mrp 
    #Replace the measure which is part of the product name with blank
    df['product_name'] = df.product_name.str.split(":").str[0].str.strip()
    #Remove duplicate entries for given product and weight
    df.drop_duplicates(subset=[  'product_name','weight' ],keep='last', inplace=True)
    #Save the results to dmart_cleaned
    df.to_csv('dmart_cleaned.csv', index=False)

# %% [markdown]
# ## Clean up for Grofers

# %%
df  = pd.read_csv("grofers.csv",  engine='python')
print(df.product_name.unique())
print(df.weight.unique())
# Out:
# ['Brooke Bond 3 Roses Dust Tea' 'Grofers Happy Day Kadak Tea'
#  'Grofers Happy Day Prime Gold Tea' '7UP Nimbooz Soft Drink (Bottle)'
#  'Pepsi Soft Drink (Bottle) - Pack of 2'
#  'Sprite Lime Flavoured Soft Drink (Bottle)' 'Pepsi Soft Drink (Bottle)'
#  'Real Activ 100% Mixed Fruit Juice'
#  'Real Activ 100% Tender Coconut Water - Pack of 6'
#  'Protinex Tasty Chocolate Flavour Acti Pro 5 Health Drink'
#  'Protinex Tasty Chocolate Flavour Acti Pro 5 Health Drink (Tin)'
#  'Grofers Happy Day Crunchy Peanut Butter'
#  'Everest Tikhalal Red Chilli Powder'
#  'Family Farm Economy Steam 25 kg Steam Sonamasuri Rice'
#  'Family Farm Standard 25 kg Raw Sonamasuri Rice'
#  'Family Farm Super Premium 25 kg Raw Sonamasuri Rice'
#  'Family Farm Standard Steam 25 kg Steam Sonamasuri Rice'
#  'Kohinoor Charminar Rozana Basmati Rice' 'Santoor Sandal & Turmeric Soap'
#  'Active Wheel 2 in 1 Clean & Fresh Detergent Powder'
#  'Ariel Complete Detergent Powder'
#  "Grofers Mother's Choice Red Chilli Powder"
#  'Tide Plus Extra Power Jasmine & Rose Detergent Powder - Brand Offer'
#  'Surf Excel Quick Wash Detergent Powder'
#  'Stayfree Secure Cottony Soft Sanitary Pads (Regular Wings)'
#  'Stayfree Secure Cottony Soft Sanitary Pads (Extra Large Wings)'
#  'Whisper Ultra Clean Sanitary Pads (XL+)'
#  'Step-Out Sanitary Pads (XL+) - Pack of 3'
#  'Pee Safe Biodegradable Overnight Sanitary Pads'
#  'Sunsilk Stunning Black Shine Shampoo'
#  'Sunsilk Lusciously Thick & Long Shampoo'
#  'Head & Shoulders Anti Hairfall Anti Dandruff Shampoo'
#  'Meera Strong & Healthy Shampoo'
#  'Sunsilk Nourishing Soft & Smooth Shampoo'
#  'Sunsilk Long & Healthy Growth with Biotin Shampoo'
#  'Brooke Bond Taj Mahal Tea Bags (Carton)' 'Sweet Tamarind (Imli) - Box'
#  'Potato' 'Tata Chakra Gold Elaichi Tea' 'Tata Chakra Gold Tea'
#  'Grofers Happy Day Kadak Tea - 250 g'
#  'Tata Sampann Unpolished Arhar Dal/Toor Dal'
#  "Grofers Mother's Choice Unpolished Arhar Dal/Toor Dal"
#  'Safe Harvest Pesticide Free Arhar Dal/Toor Dal'
#  'Tresemme Hair Fall Defense Shampoo'
#  'Tresemme Nourish & Replenish Shampoo' 'Tresemme Keratin Smooth Shampoo'
#  'Tropicana Mixed Fruit Delight Juice - Pack of 2'
#  'Tropicana Apple Delight Juice - Pack of 2'
#  'Tropicana Orange Delight Juice - Pack of 2'
#  'Sofy Anti Bacteria Extra Long Sanitary Pads (54 Pads)'
#  'Whisper Ultra Nights Sanitary Pads (XXXL Wings)'
#  'Stayfree Secure Cottony Soft Sanitary Pads (Extra Large Wings) - Pack of 2'
#  'VWash Wow Ultra Thin Sanitary Pads (Extra Large)']
# ['500 g' '250 g' '1 kg' '350 ml' '2x600 ml' '600 ml' '2.25 l' '1 l'
#  '6x200 ml' '750 g' '400 g' '2x260 ml' '260 ml' '130 ml' '3x150 ml'
#  '135 ml' '5 l' '2 l' '250 ml' '200 ml' '100 ml' '500 ml' '300 ml'
#  '400ml + 90ml' '5x120 g' '2x75 g' '2x37 g' '5x200 g' '2x140 g' '200 g'
#  '100 g' '126 g' '150 g' '60 g' '2x36 g' '130 g' '40 g' '2(5x125 g)'
#  '5x125 g' '3x125 g' '3x100 g' '8x100 g' '650 ml' '2x300 g' '300 g'
#  '2x(2x150 g)' '6x300 ml' '2x330 ml' '2x300 ml' '6 unit' '3 units'
#  '1 unit' '4 units' '2x150 g' '400 ml' '750 ml' '2x975 ml' '2x1 l'
#  '3x500 ml' '2x500 ml' '2x(5x100) g' '5x100 g' '180 ml' '340 ml' '240 ml'
#  '220 ml' '150 ml' '3x(3x100) g' '4x75 g' '125 g' '5 kg' '1.2 l' '50 g'
#  '350 g' '25 ml' '75 ml' '4x200 ml' '6x250 ml' '190 ml' '4x125 g'
#  '2x120 g' '2x250 g' '3x75 g' '8x125 g' '340 g' '25 kg' '4 kg' '7kg + 3kg'
#  '2 kg' '20 units' '44 units' '3x20 units' '10 units' '100 units' '1  kg'
#  '580 ml' '185 ml' '54 units' '2x20 units' '30 units']

# %% [markdown]
# <font color=red>Inference: Clean up is required as follows.</font>
#
#  - There are products with combo packs. So, remove them as identifying individual product becomes tough during recommendation
#  - Remove products with weights that has invalid characters other than numbers
#  - Drop duplicate products that may have arrived due to wrong search results given by the site

# %%
#Cleanup routine for grofers
def clean_grofers_data():
    #Read the dataset
    df  = pd.read_csv("grofers.csv")
    # Pattern to identify combo packs
    searchfor = ['x', 'X', ',', 'Refills', 'Bags','Sachets','Drops','Wipes','U','Wipe','Pellets','Cubes','unit','units','tablets',"\+",'XL','L','M','S','Set','Pink']
    #Drop the rows with above patterns
    df.drop( df[ df["weight"].str.contains('|'.join(searchfor)) ].index,inplace=True  )
    #Separate weight in to weight, measure
    df[['weight','measure']] = df.weight.str.split(expand=True) 
    #Remove rows that have invalid weight entries
    df.drop( df[~df["weight"].str.replace('.','',1).str.isnumeric() ].index,inplace=True  )
    #Creae weight_measure column by combining weight and measure
    df[ 'weight_measure' ] = df.weight.str.strip() + df.measure.str.strip()
    #Check if product name has the keyword we searched for
    df['good_product_ind'] = [x[1] in x[0] for x in zip(df['product_name'], df['search_brand'])]
    #Drop the products that don;t meet the above criteria
    df.drop( df[~df["good_product_ind"] ].index,inplace=True  )    
    #Re-order columns
    df = df[['search_product','search_brand', 'shop' ,'product_name','weight', 'measure', 'weight_measure', 'mrp','special_price']]
    #Calculate discount
    df['discount'] = (df.mrp - df.special_price) *100 / df.mrp 
    #Remove duplicate entries for given product and weight
    df.drop_duplicates(subset=[  'product_name','weight'],keep='last', inplace=True)
    #Save the results to grofers_cleaned
    df.to_csv('grofers_cleaned.csv', index=False)

# %% [markdown]
# ## Clean up for All

# %%
#Run cleanup 
clean_bigbasket_data()
clean_dmart_data()
clean_grofers_data()

df_bb  = pd.read_csv("big_basket_cleaned.csv")
df_dmart  = pd.read_csv("dmart_cleaned.csv")
df_grofers  = pd.read_csv("grofers_cleaned.csv")
 
print("Bigbasket products count after cleanup:" , df_bb.shape[0] )
print("DMart products count after cleanup:" , df_dmart.shape[0] )
print("Grofers products count after cleanup:" , df_grofers.shape[0] )
# Out:
# Bigbasket products count after cleanup: 414
# DMart products count after cleanup: 130
# Grofers products count after cleanup: 88

# %% [markdown]
# # Data Integration
#
# ## Approach:
#
#  For each of the files generated in the previous section, combine them into a single file as follows
#  1. Load following scrapped and already cleaned files into separate data frames
#  >
#      - big_basket_cleaned.csv
#      - dmart_cleaned.csv
#      - grofers_cleaned.csv
#      >
#
#  2. Join all the 3 data frames into a single data frame
#  3. Sort the products based on product type and name so that related products will be together irrespective of he shop
#
#  4. Write the data frame into a final file
#       - combined.csv

# %%
#Combine cleaned files into combined.csv file
def combine_products():
    #Load cleaned files into separate dataframes 
    df_dmart  = pd.read_csv("dmart_cleaned.csv")
    df_grofers  = pd.read_csv("grofers_cleaned.csv")
    df_bb  = pd.read_csv("big_basket_cleaned.csv")
   
    #Combine these files into a single data frame
    df_combined = pd.concat([df_bb, df_dmart, df_grofers])
    
    #Sort them based on searched product and resultant product name
    df_combined.sort_values(by=[ 'search_product' , 'product_name'], inplace=True)
    #Reset the index
    df_combined = df_combined.reset_index(drop=True)
    #Store the results in final file combined.csv
    df_combined.to_csv('combined.csv', index=False)
     
    return df_combined

# %%
#Combine Products 
combine_products()
#Read combined products into data frame
df_combined  = pd.read_csv("combined.csv")
print("Final Scrapped and Cleaned Product Count:" , df_combined.shape[0] )
# Out:
# Final Scrapped and Cleaned Product Count: 632

# %% [markdown]
# # EDA & RECOMMENDATION
#
# ## Approach:
#
#  For each of the files generated in the previous section, combine them into a single file as follows
#  1. Load following scrapped, cleaned and combined file into a data frame
#
#      - combined.csv
#
#
#  2. Perform EDA
#  3. Provide user interface for users to choose a product category, name and size, and recommended from which shop the user can buy and the discount

# %% [markdown]
# ## EDA

# %%
#Read the file into a dataframe
items = pd.read_csv('combined.csv')

# %%
#print shape of the combined dataset
print("The total count of products available across shops ",  items.shape[0])
# Out:
# The total count of products available across shops  632

# %%
#print the first few rows
items.head()
# Out:
#   search_product search_brand        shop  \
# 0      Bath Soap      Cinthol  Big Basket
# 1      Bath Soap      Cinthol  Big Basket
# 2      Bath Soap      Cinthol  Big Basket
# 3      Bath Soap       Dettol  Big Basket
# 4      Bath Soap       Dettol  Big Basket
#
#                                         product_name  weight measure  \
# 0  Cinthol Confidence+ Bath Soap - 99.9% Germ Pro...   100.0       g
# 1     Cinthol Cool Bath Soap - 99.9% Germ Protection   100.0       g
# 2  Cinthol Original Bath Soap - 99.9% Germ Protec...   100.0       g
# 3                     Dettol Bathing Bar Soap - Cool   125.0       g
# 4                 Dettol Bathing Bar Soap - Original   125.0       g
#
#   weight_measure    mrp  special_price  discount
# 0           100g  140.0         128.80       8.0
# 1           100g  280.0         246.40      12.0
# 2           100g   35.0          33.25       5.0
# 3           125g   50.0          47.50       5.0
# 4           125g   50.0          47.50       5.0

# %%
#Check if there are any null values in the final dataset
items.isnull().sum()
# Out:
# search_product    0
# search_brand      0
# shop              0
# product_name      0
# weight            0
# measure           0
# weight_measure    0
# mrp               0
# special_price     0
# discount          0
# dtype: int64

# %%
#Which shops are part of the dataset
items.shop.unique()
# Out:
# array(['Big Basket', 'Grofers', 'DMart'], dtype=object)

# %%
#Unique product categories
items.search_product.unique()
# Out:
# array(['Bath Soap', 'Bathroom Cleaner', 'Chana Dal', 'Coffee',
#        'Cooking Oil', 'Cooking oil', 'Deodrant', 'Face Powder',
#        'Floor Cleaner', 'Gold Coffee', 'Hair Conditioner', 'Hair Oil',
#        'Hair oil', 'Hand Wash', 'Jaggery', 'Juice', 'Mineral Water',
#        'Popcorn', 'RedChilli', 'Rice', 'Rusks', 'Sanitary Pads',
#        'Shampoo', 'Soft Drink', 'Tamarind', 'Tea', 'Tooth Brush',
#        'Tooth Paste'], dtype=object)

# %%
#Scatter plot for all attributes
sns.pairplot(items)
plt.show()

# %%
#Heatmap for all attributes
plt.figure(figsize = (10,8))
corr = items.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# Inference: The above heat map shows there is a tight correlation between mrp and special_price.

# %%
## How many products does each shop have to offer?
prods_shops_df = items[['shop','search_product']]
prod_shops_counts =prods_shops_df.groupby(['shop'],as_index =False).count()
prod_shops_counts.plot.bar(x="shop", y="search_product", rot=70, title="Products accross Vendors");

# %% [markdown]
# Inference: Big Basket has highest number of products available while Grofers has the least. Customers are most likely to find a product in Big Basket.

# %%
#How many products avaialble for each product category overall
products_count =prods_shops_df.groupby(['search_product'],as_index =False).count()
dataFrame = pd.DataFrame(data=products_count);
y_pos = np.arange(len(dataFrame))
# Draw a vertical bar chart
ax = dataFrame.plot.bar(x="search_product", y="shop", rot=80, title="Products and their Availability");
ax.set_xlabel("Product")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
###  Number of products sold per product category by each shop 
pd.crosstab(items.shop, items.search_product, margins=True, margins_name="Total",rownames=['shop']).T
# Out:
# shop              Big Basket  DMart  Grofers  Total
# search_product
# Bath Soap                 50      1        1     52
# Bathroom Cleaner          14      9        1     24
# Chana Dal                  5      5        5     15
# Coffee                    14      3        3     20
# Cooking Oil                2      1        0      3
# Cooking oil               16      0        5     21
# Deodrant                  23     10        5     38
# Face Powder               20      5        0     25
# Floor Cleaner             10      0        0     10
# Gold Coffee                4      5        0      9
# Hair Conditioner          18      4        3     25
# Hair Oil                   2      0        0      2
# Hair oil                  22      5        1     28
# Hand Wash                 17      9        1     27
# Jaggery                    5      5        5     15
# Juice                     20      0       12     32
# Mineral Water             12      0        0     12
# Popcorn                    2      0        0      2
# RedChilli                  5      0        5     10
# Rice                       5      5        5     15
# Rusks                      3      9        1     13
# Sanitary Pads             10      0        0     10
# Shampoo                   38     27       22     87
# Soft Drink                26      3        4     33
# Tamarind                   5      4        1     10
# Tea                       19      8        7     34
# Tooth Brush               14      0        0     14
# Tooth Paste               33     12        1     46
# Total                    414    130       88    632

# %%
#  Which Individual Products  have Discount
discounts_df = items[ (items.discount > 0.0)]
  
discounts_shop_products = discounts_df[['search_product','shop']]
discounts_per_shop =discounts_shop_products.groupby(['shop'],as_index =False).count()
ax = discounts_per_shop.plot.bar(x="shop", y="search_product", rot=70, title="Products accross Vendors with discount");
ax.set_xlabel("Shop")
ax.set_ylabel("Product count with discount")
# Out:
# Text(0, 0.5, 'Product count with discount')

# %% [markdown]
# Inference: DMart offers the most discounts. So customers looking for discounts should visit DMart.

# %% [markdown]
# ## Recommendation

# %% [markdown]
# <font color=red>Note: Ensure combined.csv file is present in current path before executing following recommendation code.</font>

# %%
#Import necessary libraries for user interface
from ipywidgets import interact, Dropdown, HTML, Layout, Box, Label
from IPython.display import display
import warnings
warnings.filterwarnings('ignore')

#Read data into dataframe
df_combined = pd.read_csv("combined.csv")

#Unique product types that the user can buy
products_list = df_combined["search_product"].unique()     

#Create dropdown widgets for the user to interact
product_type_dropdown = Dropdown(description="Product Type:", options = products_list)
product_names_dropdown = Dropdown(description="Product:")
product_sizes_dropdown = Dropdown(description="Size:")
recommendation_html = HTML(
    value=" ",
    placeholder='',
    description='',  layout={'width': 'max-content'}
)

box = Box(
    [
        Label(value='Recommendation:'),
        recommendation_html
    ]
) 
#Event handler when product category changes
def update_product_name_options(change):  
    product_type = product_type_dropdown.value         
    df_product = df_combined[  df_combined.search_product.str.lower().str.contains(product_type.lower())    ]
    products = df_product["product_name"].unique()
    product_names_dropdown.options = products
product_type_dropdown.observe(update_product_name_options )
 
#Event handler when product name changes
def update_product_size_options(change): 
    if change['name'] == 'value' and (change['new'] != change['old']):
        product_type = product_type_dropdown.value
        product_name = product_names_dropdown.value
        df_product = df_combined[  df_combined.search_product.str.lower().str.contains(product_type.lower())    ]
        product_name = product_name.replace("+", "\+")
        df_product = df_product[  df_product.product_name.str.lower().str.contains(product_name.lower())   ] 
        product_sizes = df_product["weight_measure"].unique()
        product_sizes_dropdown.options = product_sizes
product_names_dropdown.observe(update_product_size_options )

#Event handler when product size changes
def recommend_product(change):
    if change['name'] == 'value' and (change['new'] != change['old']):
        product_type = product_type_dropdown.value
        product_name = product_names_dropdown.value
        product_size = product_sizes_dropdown.value
        recommendation_html.value=""
        product_name = product_name.replace("+", "\+")
        if(product_size):
            df_final_list = df_combined[ df_combined.search_product.str.lower().str.contains(product_type.lower()) & 
                                         df_combined.product_name.str.lower().str.contains(product_name.lower()) & 
                                         df_combined.weight_measure.str.lower().str.contains(product_size.lower()) ] 
            df_final_list.sort_values(by='special_price', inplace=True)
            discount = round(  df_final_list[ "discount"].iloc[0] , 2)
            recommendation_html.value= "Buy it from <b>" + df_final_list.shop.iloc[0] + "</b> for Rs."  + str(df_final_list[ "special_price"].iloc[0])  + " discount of " + str(discount) + "%"
product_sizes_dropdown.observe(recommend_product )

#Display all user interface elements 
display(product_type_dropdown)
display(product_names_dropdown)
display(product_sizes_dropdown)
display(box)
update_product_name_options(None )
# Out:
# Dropdown(description='Product Type:', options=('Bath Soap', 'Bathroom Cleaner', 'Chana Dal', 'Coffee', 'Cookin…
# Dropdown(description='Product:', options=(), value=None)
# Dropdown(description='Size:', options=(), value=None)
# Box(children=(Label(value='Recommendation:'), HTML(value=' ', layout=Layout(width='max-content'), placeholder=…
